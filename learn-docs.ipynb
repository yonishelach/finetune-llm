# %% [markdown]
# # Fine-tuning LLM on MLRun documentation

# %%
import mlrun
import os

# %%
# TODO: Create project with better name:
project = mlrun.get_or_create_project("learn-docs-dev", user_project=True)
# TODO: Change to more exact image with appropiate tag:
project.set_default_image("yonishelach/mlrun:ds-debug-u")
project.set_source("git://github.com/yonishelach/learn-docs.git#main", pull_at_runtime=True)
# Out:
# > 2023-05-07 10:10:44,743 [info] loaded project learn-docs-dev from MLRun DB

# %%
base_path = os.path.abspath(project.context)
base_path
# Out:
# '/User/learn-docs'

# %% [markdown]
# ## Prepare MLRun documentation data

# %% [markdown]
# ### Download docs

# %%
fetch_docs = project.set_function(
    "src/download_docs.py",
    name="docs-downloader",
    handler="download_all_files",
    kind="job",
)
fetch_docs.apply(mlrun.auto_mount())

# %%
target_dir = os.path.join(base_path, "data/mlrun_docs")
# url = 'https://pandas.pydata.org/docs/user_guide/'
url = 'https://docs.mlrun.org/en/stable/'

# %%
fetch_docs_run = mlrun.run_function(
    function="docs-downloader",
    params={"target_dir": target_dir,"url": url, "html_to_text": True},
    outputs=["docs_dir"],
)
# Out:
# > 2023-05-07 10:39:12,048 [info] Storing function: {'name': 'docs-downloader-download-all-files', 'uid': 'd1d24bb9fa8447f4aa1c16139166204c', 'db': 'http://mlrun-api:8080'}
# > 2023-05-07 10:39:12,289 [info] Job is running in the background, pod: docs-downloader-download-all-files-dqsnt
# Found 127 links in https://docs.mlrun.org/en/stable/
# wrote file: architecture.txt
# wrote file: install.txt
# wrote file: tutorial_index.txt
# wrote file: tutorial_07-batch-infer.txt
# wrote file: install_remote.txt
# wrote file: install_kubernetes.txt
# wrote file: projects_run-build-deploy.txt
# wrote file: projects_project.txt
# wrote file: tutorial_03-model-serving.txt
# wrote file: install_local-docker.txt
# wrote file: projects_ci-integration.txt
# wrote file: projects_build-run-workflows-pipelines.txt
# wrote file: runtimes_functions.txt
# wrote file: projects_create-project.txt
# wrote file: runtimes_functions-architecture.txt
# wrote file: runtimes_dask-pipeline.txt
# wrote file: runtimes_dask-overview.txt
# wrote file: runtimes_spark-operator.txt
# wrote file: runtimes_horovod.txt
# wrote file: runtimes_mlrun_code_annotations.txt
# wrote file: runtimes_images.txt
# wrote file: runtimes_function-storage.txt
# wrote file: concepts_node-affinity.txt
# wrote file: runtimes_image-build.txt
# wrote file: concepts_data.txt
# wrote file: runtimes_configuring-job-resources.txt
# wrote file: store_data-items.txt
# wrote file: tutorial_01-mlrun-basics.txt
# wrote file: store_artifacts.txt
# wrote file: store_models.txt
# wrote file: feature-store_transformations.txt
# wrote file: feature-store_feature-vectors.txt
# wrote file: tutorial_02-model-training.txt
# wrote file: feature-store_end-to-end-demo_index.txt
# wrote file: feature-store_end-to-end-demo_01-ingest-datasources.txt
# wrote file: tutorial_06-add-mlops-to-code.txt
# wrote file: feature-store_end-to-end-demo_04-pipeline.txt
# wrote file: concepts_runs-workflows.txt
# wrote file: concepts_mlrun-execution-context.txt
# wrote file: concepts_submitting-tasks-jobs-to-functions.txt
# wrote file: concepts_workflow-overview.txt
# wrote file: concepts_scheduled-jobs.txt
# wrote file: serving_serving-graph.txt
# wrote file: serving_getting-started.txt
# wrote file: mlops-dev-flow.txt
# wrote file: tutorial_04-pipeline.txt
# wrote file: serving_realtime-pipelines.txt
# wrote file: tutorial_05-model-monitoring.txt
# wrote file: projects_load-project.txt
# wrote file: feature-store_basic-demo.txt
# wrote file: serving_writing-custom-steps.txt
# wrote file: install_aws-install.txt
# wrote file: serving_model-serving-get-started.txt
# wrote file: serving_available-steps.txt
# wrote file: serving_demos.txt
# wrote file: secrets.txt
# wrote file: serving_distributed-graph.txt
# wrote file: serving_pipelines-error-handling.txt
# wrote file: concepts_functions-overview.txt
# wrote file: concepts_monitoring.txt
# wrote file: serving_graph-example.txt
# wrote file: data-prep_index.txt
# wrote file: serving_graph-ha-cfg.txt
# wrote file: runtimes_dask-mlrun.txt
# wrote file: data-prep_logging_datasets.txt
# wrote file: data-prep_ingesting_data.txt
# wrote file: concepts_nuclio-real-time-functions.txt
# wrote file: development_index.txt
# wrote file: data-prep_ingest-data-fs.txt
# wrote file: runtimes_create-and-use-functions.txt
# wrote file: development_model-training-tracking.txt
# wrote file: concepts_auto-logging-mlops.txt
# wrote file: feature-store_using-spark-engine.txt
# wrote file: store_datastore.txt
# wrote file: runtimes_load-from-hub.txt
# wrote file: deployment_index.txt
# wrote file: training_working-with-data-and-model-artifacts.txt
# wrote file: serving_built-in-model-serving.txt
# wrote file: feature-store_feature-store-overview.txt
# wrote file: feature-store_retrieve-offline-data.txt
# wrote file: feature-store_feature-store.txt
# wrote file: serving_serving-overview.txt
# wrote file: serving_custom-model-serving-class.txt
# wrote file: hyper-params.txt
# wrote file: feature-store_feature-sets.txt
# wrote file: serving_model-api.txt
# wrote file: feature-store_training-serving.txt
# wrote file: training_built-in-training-function.txt
# wrote file: monitoring_index.txt
# wrote file: serving_test-deploy-model-server.txt
# wrote file: serving_canary.txt
# wrote file: api_mlrun.frameworks_index.txt
# wrote file: monitoring_initial-setup-configuration.txt
# wrote file: api_index.txt
# wrote file: feature-store_end-to-end-demo_03-deploy-serving-model.txt
# wrote file: deployment_batch_inference.txt
# wrote file: feature-store_end-to-end-demo_02-create-training-model.txt
# wrote file: monitoring_model-monitoring-deployment.txt
# wrote file: concepts_decorators-and-auto-logging.txt
# wrote file: api_mlrun.frameworks_mlrun.frameworks.tf_keras.txt
# wrote file: api_mlrun.frameworks_mlrun.frameworks.xgboost.txt
# wrote file: api_mlrun.frameworks_mlrun.frameworks.sklearn.txt
# wrote file: api_mlrun.frameworks_mlrun.frameworks.auto_mlrun.txt
# wrote file: api_mlrun.frameworks_mlrun.frameworks.pytorch.txt
# wrote file: genindex.txt
# wrote file: api_mlrun.config.txt
# wrote file: api_mlrun.artifacts.txt
# wrote file: api_mlrun.frameworks_mlrun.frameworks.lgbm.txt
# wrote file: api_mlrun.txt
# wrote file: serving_use-cases.txt
# wrote file: api_mlrun.execution.txt
# wrote file: glossary.txt
# wrote file: api_mlrun.model.txt
# wrote file: api_mlrun.platforms.txt
# wrote file: cli.txt
# wrote file: contents.txt
# wrote file: api_mlrun.datastore.txt
# wrote file: api_mlrun.runtimes.txt
# wrote file: api_mlrun.run.txt
# wrote file: api_storey.transformations.txt
# wrote file: api_mlrun.serving.txt
# wrote file: api_mlrun.feature_store.txt
# wrote file: api_mlrun.db.txt
# wrote file: api_mlrun.projects.txt
# wrote file: training_create-a-basic-training-job.txt
# > 2023-05-07 10:39:43,668 [info] To track results use the CLI: {'info_cmd': 'mlrun get run d1d24bb9fa8447f4aa1c16139166204c -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs d1d24bb9fa8447f4aa1c16139166204c -p learn-docs-dev-admin'}
# > 2023-05-07 10:39:43,668 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/d1d24bb9fa8447f4aa1c16139166204c/overview'}
# > 2023-05-07 10:39:43,669 [info] run executed, status=completed: {'name': 'docs-downloader-download-all-files'}
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>learn-docs-dev-admin</td>
#       <td><div title="d1d24bb9fa8447f4aa1c16139166204c"><a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/d1d24bb9fa8447f4aa1c16139166204c/overview" target="_blank" >...9166204c</a></div></td>
#       <td>0</td>
#       <td>May 07 10:39:28</td>
#       <td>completed</td>
#       <td>docs-downloader-download-all-files</td>
#       <td><div class="dictlist">v3io_user=admin</div><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div><div class="dictlist">mlrun/client_version=1.3.0</div><div class="dictlist">mlrun/client_python_version=3.9.16</div><div class="dictlist">host=docs-downloader-download-all-files-dqsnt</div></td>
#       <td></td>
#       <td><div class="dictlist">target_dir=/User/learn-docs/data/mlrun_docs</div><div class="dictlist">url=https://docs.mlrun.org/en/stable/</div><div class="dictlist">html_to_text=True</div></td>
#       <td></td>
#       <td><div title="v3io:///projects/learn-docs-dev-admin/artifacts/docs-downloader-download-all-files/0/docs_dir.zip">docs_dir</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result5b61cf57-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result5b61cf57-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result5b61cf57" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result5b61cf57-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/d1d24bb9fa8447f4aa1c16139166204c/overview" target="_blank">click here</a> to open in UI</b>
# > 2023-05-07 10:39:46,497 [info] run executed, status=completed: {'name': 'docs-downloader-download-all-files'}

# %%
fetch_docs_run.outputs["docs_dir"]
# Out:
# 'v3io:///projects/learn-docs-dev-admin/artifacts/docs-downloader-download-all-files/0/docs_dir.zip'

# %%
docs_dir = 'v3io:///projects/learn-docs-dev-admin/artifacts/docs-downloader-download-all-files/0/docs_dir.zip'

# %% [markdown]
# ### Prepare docs dataset

# %%
data_preparation = project.set_function(
    "src/data_prep.py",
    name="data-prep",
    handler="prepare_dataset",
    kind="job",
)
data_preparation.apply(mlrun.auto_mount())

# %%
target_dir = os.path.join(base_path, "data/mlrun_dataset")
prepare_dataset_run = mlrun.run_function(
    function="data-prep",
    params={
        "target_dir": target_dir,
        "ignored_files": ["contents", "genindex"],
        "from_text": True,
    },
    inputs={"docs_source": docs_dir},
    outputs=["train_dataset", "test_dataset", "additional_params"],
)
# Out:
# > 2023-05-07 10:57:32,672 [info] Storing function: {'name': 'data-prep-prepare-dataset', 'uid': 'feb75f95a1174d2aa00b3fb92cac0736', 'db': 'http://mlrun-api:8080'}
# > 2023-05-07 10:57:32,931 [info] Job is running in the background, pod: data-prep-prepare-dataset-mc6st
# Added to dataset: api_index
# Added to dataset: api_mlrun.artifacts
# Added to dataset: api_mlrun.config
# Added to dataset: api_mlrun.datastore
# Added to dataset: api_mlrun.db
# Added to dataset: api_mlrun.execution
# Added to dataset: api_mlrun.feature_store
# Added to dataset: api_mlrun.frameworks_index
# Added to dataset: api_mlrun.frameworks_mlrun.frameworks.auto_mlrun
# Added to dataset: api_mlrun.frameworks_mlrun.frameworks.lgbm
# Added to dataset: api_mlrun.frameworks_mlrun.frameworks.pytorch
# Added to dataset: api_mlrun.frameworks_mlrun.frameworks.sklearn
# Added to dataset: api_mlrun.frameworks_mlrun.frameworks.tf_keras
# Added to dataset: api_mlrun.frameworks_mlrun.frameworks.xgboost
# Added to dataset: api_mlrun.model
# Added to dataset: api_mlrun.platforms
# Added to dataset: api_mlrun.projects
# Added to dataset: api_mlrun.run
# Added to dataset: api_mlrun.runtimes
# Added to dataset: api_mlrun.serving
# Added to dataset: api_mlrun
# Added to dataset: api_storey.transformations
# Added to dataset: architecture
# Added to dataset: cli
# Added to dataset: concepts_auto-logging-mlops
# Added to dataset: concepts_data
# Added to dataset: concepts_decorators-and-auto-logging
# Added to dataset: concepts_functions-overview
# Added to dataset: concepts_mlrun-execution-context
# Added to dataset: concepts_monitoring
# Added to dataset: concepts_node-affinity
# Added to dataset: concepts_nuclio-real-time-functions
# Added to dataset: concepts_runs-workflows
# Added to dataset: concepts_scheduled-jobs
# Added to dataset: concepts_submitting-tasks-jobs-to-functions
# Added to dataset: concepts_workflow-overview
# Added to dataset: data-prep_index
# Added to dataset: data-prep_ingest-data-fs
# Added to dataset: data-prep_ingesting_data
# Added to dataset: data-prep_logging_datasets
# Added to dataset: deployment_batch_inference
# Added to dataset: deployment_index
# Added to dataset: development_index
# Added to dataset: development_model-training-tracking
# Added to dataset: feature-store_basic-demo
# Added to dataset: feature-store_end-to-end-demo_01-ingest-datasources
# Added to dataset: feature-store_end-to-end-demo_02-create-training-model
# Added to dataset: feature-store_end-to-end-demo_03-deploy-serving-model
# Added to dataset: feature-store_end-to-end-demo_04-pipeline
# Added to dataset: feature-store_end-to-end-demo_index
# Added to dataset: feature-store_feature-sets
# Added to dataset: feature-store_feature-store-overview
# Added to dataset: feature-store_feature-store
# Added to dataset: feature-store_feature-vectors
# Added to dataset: feature-store_retrieve-offline-data
# Added to dataset: feature-store_training-serving
# Added to dataset: feature-store_transformations
# Added to dataset: feature-store_using-spark-engine
# Added to dataset: glossary
# Added to dataset: hyper-params
# Added to dataset: install
# Added to dataset: install_aws-install
# Added to dataset: install_kubernetes
# Added to dataset: install_local-docker
# Added to dataset: install_remote
# Added to dataset: mlops-dev-flow
# Added to dataset: monitoring_index
# Added to dataset: monitoring_initial-setup-configuration
# Added to dataset: monitoring_model-monitoring-deployment
# Added to dataset: projects_build-run-workflows-pipelines
# Added to dataset: projects_ci-integration
# Added to dataset: projects_create-project
# Added to dataset: projects_load-project
# Added to dataset: projects_project
# Added to dataset: projects_run-build-deploy
# Added to dataset: runtimes_configuring-job-resources
# Added to dataset: runtimes_create-and-use-functions
# Added to dataset: runtimes_dask-mlrun
# Added to dataset: runtimes_dask-overview
# Added to dataset: runtimes_dask-pipeline
# Added to dataset: runtimes_function-storage
# Added to dataset: runtimes_functions-architecture
# Added to dataset: runtimes_functions
# Added to dataset: runtimes_horovod
# Added to dataset: runtimes_image-build
# Added to dataset: runtimes_images
# Added to dataset: runtimes_load-from-hub
# Added to dataset: secrets
# Added to dataset: runtimes_mlrun_code_annotations
# Added to dataset: runtimes_spark-operator
# Added to dataset: serving_available-steps
# Added to dataset: serving_built-in-model-serving
# Added to dataset: serving_canary
# Added to dataset: serving_custom-model-serving-class
# Added to dataset: serving_demos
# Added to dataset: serving_distributed-graph
# Added to dataset: serving_getting-started
# Added to dataset: serving_graph-example
# Added to dataset: serving_graph-ha-cfg
# Added to dataset: serving_model-api
# Added to dataset: serving_model-serving-get-started
# Added to dataset: serving_pipelines-error-handling
# Added to dataset: serving_realtime-pipelines
# Added to dataset: serving_serving-graph
# Added to dataset: serving_serving-overview
# Added to dataset: serving_test-deploy-model-server
# Added to dataset: serving_use-cases
# Added to dataset: serving_writing-custom-steps
# Added to dataset: store_artifacts
# Added to dataset: store_data-items
# Added to dataset: store_datastore
# Added to dataset: store_models
# Added to dataset: training_built-in-training-function
# Added to dataset: training_create-a-basic-training-job
# Added to dataset: training_working-with-data-and-model-artifacts
# Added to dataset: tutorial_01-mlrun-basics
# Added to dataset: tutorial_02-model-training
# Added to dataset: tutorial_03-model-serving
# Added to dataset: tutorial_04-pipeline
# Added to dataset: tutorial_05-model-monitoring
# Added to dataset: tutorial_06-add-mlops-to-code
# Added to dataset: tutorial_07-batch-infer
# Added to dataset: tutorial_index
# ===== Ignored files: =====
# /tmp/tmp16ncn1tc/contents.txt
# /tmp/tmp16ncn1tc/genindex.txt
# Downloading and preparing dataset json/mlrun_dataset to /root/.cache/huggingface/datasets/json/mlrun_dataset-d81059722b941bee/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4...
# Downloading data files: 100%|██████████| 1/1 [00:00<00:00, 2166.48it/s]
# Extracting data files: 100%|██████████| 1/1 [00:00<00:00, 111.80it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/mlrun_dataset-d81059722b941bee/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4. Subsequent calls will reuse this data.
# 100%|██████████| 1/1 [00:00<00:00, 725.03it/s]
# > 2023-05-07 10:57:51,849 [info] To track results use the CLI: {'info_cmd': 'mlrun get run feb75f95a1174d2aa00b3fb92cac0736 -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs feb75f95a1174d2aa00b3fb92cac0736 -p learn-docs-dev-admin'}
# > 2023-05-07 10:57:51,849 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/feb75f95a1174d2aa00b3fb92cac0736/overview'}
# > 2023-05-07 10:57:51,850 [info] run executed, status=completed: {'name': 'data-prep-prepare-dataset'}
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>learn-docs-dev-admin</td>
#       <td><div title="feb75f95a1174d2aa00b3fb92cac0736"><a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/feb75f95a1174d2aa00b3fb92cac0736/overview" target="_blank" >...2cac0736</a></div></td>
#       <td>0</td>
#       <td>May 07 10:57:48</td>
#       <td>completed</td>
#       <td>data-prep-prepare-dataset</td>
#       <td><div class="dictlist">v3io_user=admin</div><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div><div class="dictlist">mlrun/client_version=1.3.0</div><div class="dictlist">mlrun/client_python_version=3.9.16</div><div class="dictlist">host=data-prep-prepare-dataset-mc6st</div></td>
#       <td><div title="v3io:///projects/learn-docs-dev-admin/artifacts/docs-downloader-download-all-files/0/docs_dir.zip">docs_source</div></td>
#       <td><div class="dictlist">target_dir=/User/learn-docs/data/mlrun_dataset</div><div class="dictlist">ignored_files=['contents', 'genindex']</div><div class="dictlist">from_text=True</div></td>
#       <td></td>
#       <td><div title="v3io:///projects/learn-docs-dev-admin/artifacts/data-prep-prepare-dataset/0/train_dataset.parquet">train_dataset</div><div title="v3io:///projects/learn-docs-dev-admin/artifacts/data-prep-prepare-dataset/0/test_dataset.parquet">test_dataset</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result0318622d-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result0318622d-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result0318622d" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result0318622d-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/feb75f95a1174d2aa00b3fb92cac0736/overview" target="_blank">click here</a> to open in UI</b>
# > 2023-05-07 10:57:57,129 [info] run executed, status=completed: {'name': 'data-prep-prepare-dataset'}

# %%
train_dataset = "store://datasets/deepspeed-admin/data-prep-prepare-dataset_train_dataset#0:latest"
test_dataset = "store://datasets/deepspeed-admin/data-prep-prepare-dataset_test_dataset#0:latest"

# %% [markdown]
# ## Test pretrained LLM from HuggingFace hub without fine-tuning

# %%
test_pretrained_llm = project.set_function(
    "src/test_model.py",
    name="test-llm",
    handler="load_my_model",
    kind="job",
)
test_pretrained_llm.apply(mlrun.auto_mount())

# %%
mlrun.run_function(function="test-llm", params={"model_name": "gpt2"})
# Out:
# > 2023-05-07 10:59:36,018 [info] Storing function: {'name': 'test-llm-load-my-model', 'uid': 'ad0700a3c0bf40a7b7a4bc4967368818', 'db': 'http://mlrun-api:8080'}
# > 2023-05-07 10:59:36,268 [info] Job is running in the background, pod: test-llm-load-my-model-wt9km
# Downloading (…)olve/main/vocab.json: 100%|██████████| 1.04M/1.04M [00:00<00:00, 20.3MB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 12.8MB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 665/665 [00:00<00:00, 225kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 548M/548M [00:01<00:00, 482MB/s]
# Downloading (…)neration_config.json: 100%|██████████| 124/124 [00:00<00:00, 17.3kB/s]
# Generated response: What is mlrun?
#
# mlrun is a Python library for running Python code in a Python interpreter. It is a Python wrapper around the standard library.
#
# It is a Python wrapper around the standard library. It is a Python wrapper around the standard library. It is a Python wrapper around the standard library. It is a Python wrapper around the standard library. It is a Python wrapper around the standard library. It is a Python wrapper around the standard library. It is a Python wrapper around
# Generated response: What is an MLRun function?
#
# An MLRun function is a function that takes a list of arguments and returns a list of the arguments.
#
# The following example shows how to use an MLRun function to run a program.
#
# import std.stdio import std.time import std.time.Duration import std.time.Duration.Duration as T import std.time.Duration.Duration.Duration as T.Duration import std.time.Duration.Duration.Duration.
# > 2023-05-07 11:00:57,255 [info] To track results use the CLI: {'info_cmd': 'mlrun get run ad0700a3c0bf40a7b7a4bc4967368818 -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs ad0700a3c0bf40a7b7a4bc4967368818 -p learn-docs-dev-admin'}
# > 2023-05-07 11:00:57,256 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/ad0700a3c0bf40a7b7a4bc4967368818/overview'}
# > 2023-05-07 11:00:57,256 [info] run executed, status=completed: {'name': 'test-llm-load-my-model'}
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>learn-docs-dev-admin</td>
#       <td><div title="ad0700a3c0bf40a7b7a4bc4967368818"><a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/ad0700a3c0bf40a7b7a4bc4967368818/overview" target="_blank" >...67368818</a></div></td>
#       <td>0</td>
#       <td>May 07 10:59:51</td>
#       <td>completed</td>
#       <td>test-llm-load-my-model</td>
#       <td><div class="dictlist">v3io_user=admin</div><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div><div class="dictlist">mlrun/client_version=1.3.0</div><div class="dictlist">mlrun/client_python_version=3.9.16</div><div class="dictlist">host=test-llm-load-my-model-wt9km</div></td>
#       <td></td>
#       <td><div class="dictlist">model_name=gpt2</div></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="resultd53f3591-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="resultd53f3591-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="resultd53f3591" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="resultd53f3591-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/ad0700a3c0bf40a7b7a4bc4967368818/overview" target="_blank">click here</a> to open in UI</b>
# > 2023-05-07 11:01:02,758 [info] run executed, status=completed: {'name': 'test-llm-load-my-model'}

# %% [markdown]
# ## Fine-tune this LLM with MLRun dataset

# %%
trainer = project.set_function(
    "src/trainer.py",
    name="hugging_face_classifier_trainer",
    kind="mpijob",
    with_repo=True,
)
trainer.spec.replicas = 4
trainer.with_requests(cpu=5, mem="5Gi")
trainer.with_limits(gpus=1, cpu=8, mem="50Gi")


trainer.apply(mlrun.auto_mount())
trainer.save()
# Out:
# Names with underscore '_' are about to be deprecated, use dashes '-' instead. Replacing underscores with dashes.
# 'db://learn-docs-dev-admin/hugging-face-classifier-trainer'

# %%
params = {
    "model_name": "gpt2-ft-mlrun",
    "pretrained_model": "gpt2",
    "pretrained_tokenizer": "gpt2",
    "model_class": "transformers.GPT2LMHeadModel",
    "tokenizer_class": "transformers.GPT2Tokenizer",
    "random_state": 42,
    "TRAIN_output_dir": os.path.join(base_path, "finetuning-mlrun-data"),
    "TRAIN_overwrite_output_dir": True,
    "TRAIN_num_train_epochs": 2,
    "TRAIN_fp16": True,
    "TRAIN_bf16": False,
    "TRAIN_per_device_train_batch_size": 4,
    "TRAIN_per_device_eval_batch_size": 4,
    "TRAIN_save_steps": 10000,
    "TRAIN_save_total_limit": 2,
    "TRAIN_deepspeed": os.path.join(base_path, "deepspeed_config/stage3.json"),
}

# %%
training_run = mlrun.run_function(
    function="hugging_face_classifier_trainer",
    name="trainer",
    inputs={
            "dataset": train_dataset,  # prepare_dataset_run.outputs["train_dataset"],
            "test_set": test_dataset  # prepare_dataset_run.outputs["test_dataset"],
        },
    params=params,
    handler="train",
    # outputs=["model"],
)
# Out:
# > 2023-05-07 11:01:02,902 [info] Storing function: {'name': 'trainer', 'uid': 'c254cab12e9c447190295db829ca58e2', 'db': 'http://mlrun-api:8080'}
# > 2023-05-07 11:01:31,536 [info] MpiJob trainer-f8a2010b launcher pod trainer-f8a2010b-launcher state active
# + POD_NAME=trainer-f8a2010b-worker-0
# + shift
# + /opt/kube/kubectl exec trainer-f8a2010b-worker-0 -- /bin/sh -c  orted -mca ess "env" -mca ess_base_jobid "3238461440" -mca ess_base_vpid 1 -mca ess_base_num_procs "5" -mca orte_node_regex "trainer-f[1:8]a2010b-launcher,trainer-f[1:8]a2010b-worker-0,trainer-f[1:8]a2010b-worker-1,trainer-f[1:8]a2010b-worker-2,trainer-f[1:8]a2010b-worker-3@0(5)" -mca orte_hnp_uri "3238461440.0;tcp://192.168.139.248:39719" -mca plm "rsh" --tree-spawn -mca routed "radix" -mca orte_parent_uri "3238461440.0;tcp://192.168.139.248:39719" -mca plm_rsh_agent "/etc/mpi/kubexec.sh" -mca orte_default_hostfile "/etc/mpi/hostfile" -mca pmix "^s1,s2,cray,isolated"
# + POD_NAME=trainer-f8a2010b-worker-3
# + shift
# + /opt/kube/kubectl exec trainer-f8a2010b-worker-3 -- /bin/sh -c  orted -mca ess "env" -mca ess_base_jobid "3238461440" -mca ess_base_vpid 4 -mca ess_base_num_procs "5" -mca orte_node_regex "trainer-f[1:8]a2010b-launcher,trainer-f[1:8]a2010b-worker-0,trainer-f[1:8]a2010b-worker-1,trainer-f[1:8]a2010b-worker-2,trainer-f[1:8]a2010b-worker-3@0(5)" -mca orte_hnp_uri "3238461440.0;tcp://192.168.139.248:39719" -mca plm "rsh" --tree-spawn -mca routed "radix" -mca orte_parent_uri "3238461440.0;tcp://192.168.139.248:39719" -mca plm_rsh_agent "/etc/mpi/kubexec.sh" -mca orte_default_hostfile "/etc/mpi/hostfile" -mca pmix "^s1,s2,cray,isolated"
# + POD_NAME=trainer-f8a2010b-worker-2
# + shift
# + /opt/kube/kubectl exec trainer-f8a2010b-worker-2 -- /bin/sh -c  orted -mca ess "env" -mca ess_base_jobid "3238461440" -mca ess_base_vpid 3 -mca ess_base_num_procs "5" -mca orte_node_regex "trainer-f[1:8]a2010b-launcher,trainer-f[1:8]a2010b-worker-0,trainer-f[1:8]a2010b-worker-1,trainer-f[1:8]a2010b-worker-2,trainer-f[1:8]a2010b-worker-3@0(5)" -mca orte_hnp_uri "3238461440.0;tcp://192.168.139.248:39719" -mca plm "rsh" --tree-spawn -mca routed "radix" -mca orte_parent_uri "3238461440.0;tcp://192.168.139.248:39719" -mca plm_rsh_agent "/etc/mpi/kubexec.sh" -mca orte_default_hostfile "/etc/mpi/hostfile" -mca pmix "^s1,s2,cray,isolated"
# + POD_NAME=trainer-f8a2010b-worker-1
# + shift
# + /opt/kube/kubectl exec trainer-f8a2010b-worker-1 -- /bin/sh -c  orted -mca ess "env" -mca ess_base_jobid "3238461440" -mca ess_base_vpid 2 -mca ess_base_num_procs "5" -mca orte_node_regex "trainer-f[1:8]a2010b-launcher,trainer-f[1:8]a2010b-worker-0,trainer-f[1:8]a2010b-worker-1,trainer-f[1:8]a2010b-worker-2,trainer-f[1:8]a2010b-worker-3@0(5)" -mca orte_hnp_uri "3238461440.0;tcp://192.168.139.248:39719" -mca plm "rsh" --tree-spawn -mca routed "radix" -mca orte_parent_uri "3238461440.0;tcp://192.168.139.248:39719" -mca plm_rsh_agent "/etc/mpi/kubexec.sh" -mca orte_default_hostfile "/etc/mpi/hostfile" -mca pmix "^s1,s2,cray,isolated"
# > 2023-05-07 11:01:36,184 [info] extracting source from git://github.com/yonishelach/learn-docs.git#main to /mlrun/code
# > 2023-05-07 11:01:36,185 [info] extracting source from git://github.com/yonishelach/learn-docs.git#main to /mlrun/code
# > 2023-05-07 11:01:36,185 [info] extracting source from git://github.com/yonishelach/learn-docs.git#main to /mlrun/code
# > 2023-05-07 11:01:36,185 [info] extracting source from git://github.com/yonishelach/learn-docs.git#main to /mlrun/code
# Downloading (…)olve/main/vocab.json: 100%|██████████| 1.04M/1.04M [00:00<00:00, 20.5MB/s]
# Downloading (…)olve/main/vocab.json: 100%|██████████| 1.04M/1.04M [00:00<00:00, 21.0MB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 26.6MB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 12.6MB/s]
# Downloading (…)olve/main/vocab.json: 100%|██████████| 1.04M/1.04M [00:00<00:00, 20.9MB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 665/665 [00:00<00:00, 240kB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 665/665 [00:00<00:00, 229kB/s]
# Downloading (…)olve/main/vocab.json: 100%|██████████| 1.04M/1.04M [00:00<00:00, 20.4MB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 12.0MB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 12.1MB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 665/665 [00:00<00:00, 244kB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 665/665 [00:00<00:00, 220kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 548M/548M [00:01<00:00, 431MB/s]
# Downloading pytorch_model.bin: 100%|██████████| 548M/548M [00:01<00:00, 449MB/s]
# Downloading pytorch_model.bin: 100%|██████████| 548M/548M [00:01<00:00, 370MB/s]
# Downloading (…)neration_config.json: 100%|██████████| 124/124 [00:00<00:00, 16.6kB/s]
# [2023-05-07 11:02:02,752] [INFO] [comm.py:570:init_distributed] Not using the DeepSpeed or dist launchers, attempting to detect MPI environment...
# Downloading (…)neration_config.json: 100%|██████████| 124/124 [00:00<00:00, 15.9kB/s]
# [2023-05-07 11:02:03,037] [INFO] [comm.py:570:init_distributed] Not using the DeepSpeed or dist launchers, attempting to detect MPI environment...
# Downloading (…)neration_config.json: 100%|██████████| 124/124 [00:00<00:00, 17.1kB/s]
# [2023-05-07 11:02:03,185] [INFO] [comm.py:570:init_distributed] Not using the DeepSpeed or dist launchers, attempting to detect MPI environment...
# Downloading pytorch_model.bin: 100%|██████████| 548M/548M [00:01<00:00, 534MB/s]
# Downloading (…)neration_config.json: 100%|██████████| 124/124 [00:00<00:00, 18.5kB/s]
# [2023-05-07 11:02:13,744] [INFO] [comm.py:570:init_distributed] Not using the DeepSpeed or dist launchers, attempting to detect MPI environment...
# [2023-05-07 11:02:13,861] [INFO] [comm.py:620:mpi_discovery] Discovered MPI settings of world_rank=1, local_rank=0, world_size=4, master_addr=192.168.245.136, master_port=29500
# [2023-05-07 11:02:13,861] [INFO] [comm.py:620:mpi_discovery] Discovered MPI settings of world_rank=3, local_rank=0, world_size=4, master_addr=192.168.245.136, master_port=29500
# [2023-05-07 11:02:13,861] [INFO] [comm.py:620:mpi_discovery] Discovered MPI settings of world_rank=2, local_rank=0, world_size=4, master_addr=192.168.245.136, master_port=29500
# [2023-05-07 11:02:13,862] [INFO] [comm.py:620:mpi_discovery] Discovered MPI settings of world_rank=0, local_rank=0, world_size=4, master_addr=192.168.245.136, master_port=29500
# [2023-05-07 11:02:13,862] [INFO] [comm.py:586:init_distributed] Initializing TorchBackend in DeepSpeed with backend nccl
# 2023-05-07 11:02:14,933 [info] Added key: store_based_barrier_key:1 to store for rank: 1
# 2023-05-07 11:02:14,974 [info] Added key: store_based_barrier_key:1 to store for rank: 3
# 2023-05-07 11:02:15,019 [info] Added key: store_based_barrier_key:1 to store for rank: 0
# 2023-05-07 11:02:15,068 [info] Added key: store_based_barrier_key:1 to store for rank: 2
# 2023-05-07 11:02:15,069 [info] Rank 2: Completed store-based barrier for key:store_based_barrier_key:1 with 4 nodes.
# 2023-05-07 11:02:15,071 [info] Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 4 nodes.
# 2023-05-07 11:02:15,076 [info] Rank 1: Completed store-based barrier for key:store_based_barrier_key:1 with 4 nodes.
# 2023-05-07 11:02:15,076 [info] Rank 3: Completed store-based barrier for key:store_based_barrier_key:1 with 4 nodes.
# > 2023-05-07 11:02:15,086 [info] training 'gpt2-ft-mlrun'
# > 2023-05-07 11:02:15,093 [info] training 'gpt2-ft-mlrun'
# > 2023-05-07 11:02:15,095 [info] training 'gpt2-ft-mlrun'
# > 2023-05-07 11:02:15,095 [info] training 'gpt2-ft-mlrun'
# 2023-05-07 11:02:18,335 [info] Added key: store_based_barrier_key:2 to store for rank: 3
# 2023-05-07 11:02:18,351 [info] Added key: store_based_barrier_key:2 to store for rank: 2
# 2023-05-07 11:02:18,388 [info] Added key: store_based_barrier_key:2 to store for rank: 1
# 2023-05-07 11:02:18,542 [info] Added key: store_based_barrier_key:2 to store for rank: 0
# 2023-05-07 11:02:18,542 [info] Rank 0: Completed store-based barrier for key:store_based_barrier_key:2 with 4 nodes.
# 2023-05-07 11:02:18,545 [info] Rank 2: Completed store-based barrier for key:store_based_barrier_key:2 with 4 nodes.
# 2023-05-07 11:02:18,550 [info] Rank 3: Completed store-based barrier for key:store_based_barrier_key:2 with 4 nodes.
# 2023-05-07 11:02:18,552 [info] Rank 1: Completed store-based barrier for key:store_based_barrier_key:2 with 4 nodes.
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/cpu_adam...
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/cpu_adam...
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/cpu_adam...
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/cpu_adam...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] /opt/conda/bin/nvcc  -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_70,code=compute_70 -gencode=arch=compute_70,code=sm_70 --compiler-options '-fPIC' -O3 --use_fast_math -std=c++14 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -gencode=arch=compute_70,code=sm_70 -gencode=arch=compute_70,code=compute_70 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/common/custom_cuda_kernel.cu -o custom_cuda_kernel.cuda.o
# [1/3] /opt/conda/bin/nvcc  -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_70,code=compute_70 -gencode=arch=compute_70,code=sm_70 --compiler-options '-fPIC' -O3 --use_fast_math -std=c++14 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -gencode=arch=compute_70,code=sm_70 -gencode=arch=compute_70,code=compute_70 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/common/custom_cuda_kernel.cu -o custom_cuda_kernel.cuda.o
# [1/3] /opt/conda/bin/nvcc  -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_70,code=compute_70 -gencode=arch=compute_70,code=sm_70 --compiler-options '-fPIC' -O3 --use_fast_math -std=c++14 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -gencode=arch=compute_70,code=sm_70 -gencode=arch=compute_70,code=compute_70 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/common/custom_cuda_kernel.cu -o custom_cuda_kernel.cuda.o
# [1/3] /opt/conda/bin/nvcc  -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_70,code=compute_70 -gencode=arch=compute_70,code=sm_70 --compiler-options '-fPIC' -O3 --use_fast_math -std=c++14 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -gencode=arch=compute_70,code=sm_70 -gencode=arch=compute_70,code=compute_70 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/common/custom_cuda_kernel.cu -o custom_cuda_kernel.cuda.o
# [2/3] c++ -MMD -MF cpu_adam.o.d -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -O3 -std=c++14 -g -Wno-reorder -L/opt/conda/lib64 -lcudart -lcublas -g -march=native -fopenmp -D__AVX256__ -D__ENABLE_CUDA__ -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/adam/cpu_adam.cpp -o cpu_adam.o
# [2/3] c++ -MMD -MF cpu_adam.o.d -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -O3 -std=c++14 -g -Wno-reorder -L/opt/conda/lib64 -lcudart -lcublas -g -march=native -fopenmp -D__AVX256__ -D__ENABLE_CUDA__ -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/adam/cpu_adam.cpp -o cpu_adam.o
# [3/3] c++ cpu_adam.o custom_cuda_kernel.cuda.o -shared -lcurand -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda_cu -ltorch_cuda_cpp -ltorch -ltorch_python -L/opt/conda/lib64 -lcudart -o cpu_adam.so
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 40.340173959732056 seconds
# [3/3] c++ cpu_adam.o custom_cuda_kernel.cuda.o -shared -lcurand -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda_cu -ltorch_cuda_cpp -ltorch -ltorch_python -L/opt/conda/lib64 -lcudart -o cpu_adam.so
# Loading extension module cpu_adam...
# [2/3] c++ -MMD -MF cpu_adam.o.d -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -O3 -std=c++14 -g -Wno-reorder -L/opt/conda/lib64 -lcudart -lcublas -g -march=native -fopenmp -D__AVX256__ -D__ENABLE_CUDA__ -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/adam/cpu_adam.cpp -o cpu_adam.o
# Time to load cpu_adam op: 40.457810401916504 seconds
# [2/3] c++ -MMD -MF cpu_adam.o.d -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -O3 -std=c++14 -g -Wno-reorder -L/opt/conda/lib64 -lcudart -lcublas -g -march=native -fopenmp -D__AVX256__ -D__ENABLE_CUDA__ -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/adam/cpu_adam.cpp -o cpu_adam.o
# [3/3] c++ cpu_adam.o custom_cuda_kernel.cuda.o -shared -lcurand -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda_cu -ltorch_cuda_cpp -ltorch -ltorch_python -L/opt/conda/lib64 -lcudart -o cpu_adam.so
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 41.021918058395386 seconds
# [3/3] c++ cpu_adam.o custom_cuda_kernel.cuda.o -shared -lcurand -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda_cu -ltorch_cuda_cpp -ltorch -ltorch_python -L/opt/conda/lib64 -lcudart -o cpu_adam.so
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 41.20827794075012 seconds
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/utils...
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/utils...
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/utils...
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/utils...
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/2] c++ -MMD -MF flatten_unflatten.o.d -DTORCH_EXTENSION_NAME=utils -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/utils/flatten_unflatten.cpp -o flatten_unflatten.o
# [1/2] c++ -MMD -MF flatten_unflatten.o.d -DTORCH_EXTENSION_NAME=utils -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/utils/flatten_unflatten.cpp -o flatten_unflatten.o
# [2/2] c++ flatten_unflatten.o -shared -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -ltorch_cpu -ltorch -ltorch_python -o utils.so
# Loading extension module utils...
# Time to load utils op: 23.287763833999634 seconds
# [2/2] c++ flatten_unflatten.o -shared -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -ltorch_cpu -ltorch -ltorch_python -o utils.so
# Loading extension module utils...
# Time to load utils op: 23.248828649520874 seconds
# [1/2] c++ -MMD -MF flatten_unflatten.o.d -DTORCH_EXTENSION_NAME=utils -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/utils/flatten_unflatten.cpp -o flatten_unflatten.o
# [2/2] c++ flatten_unflatten.o -shared -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -ltorch_cpu -ltorch -ltorch_python -o utils.so
# Loading extension module utils...
# Time to load utils op: 23.270780563354492 seconds
# [1/2] c++ -MMD -MF flatten_unflatten.o.d -DTORCH_EXTENSION_NAME=utils -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/utils/flatten_unflatten.cpp -o flatten_unflatten.o
# [2/2] c++ flatten_unflatten.o -shared -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -ltorch_cpu -ltorch -ltorch_python -o utils.so
# Loading extension module utils...
# Time to load utils op: 23.85049605369568 seconds
# Parameter Offload: Total persistent parameters: 121344 in 98 params
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0005824565887451172 seconds
# Time to load utils op: 0.0005578994750976562 seconds
# Time to load utils op: 0.0006458759307861328 seconds
#   0%|          | 0/18 [00:00<?, ?it/s]Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0005123615264892578 seconds
# {'train_runtime': 17.0458, 'train_samples_per_second': 15.84, 'train_steps_per_second': 1.056, 'train_loss': 2.9337022569444446, 'epoch': 2.0}
# {'train_runtime': 17.032, 'train_samples_per_second': 15.853, 'train_steps_per_second': 1.057, 'train_loss': 2.7799479166666665, 'epoch': 2.0}
# {'train_runtime': 17.0495, 'train_samples_per_second': 15.836, 'train_steps_per_second': 1.056, 'train_loss': 2.9520399305555554, 'epoch': 2.0}
# {'train_runtime': 16.752, 'train_samples_per_second': 16.118, 'train_steps_per_second': 1.075, 'train_loss': 2.9049479166666665, 'epoch': 2.0}
# 100%|██████████| 18/18 [00:17<00:00,  1.06it/s]
# 100%|██████████| 18/18 [00:17<00:00,  1.06it/s]
# 100%|██████████| 18/18 [00:17<00:00,  1.06it/s]
# 100%|██████████| 18/18 [00:16<00:00,  1.07it/s]
# > 2023-05-07 11:03:52,560 [info] To track results use the CLI: {'info_cmd': 'mlrun get run c254cab12e9c447190295db829ca58e2 -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs c254cab12e9c447190295db829ca58e2 -p learn-docs-dev-admin'}
# > 2023-05-07 11:03:52,560 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/c254cab12e9c447190295db829ca58e2/overview'}
# > 2023-05-07 11:03:52,561 [info] run executed, status=running: {'name': 'trainer'}
# > 2023-05-07 11:03:52,566 [info] To track results use the CLI: {'info_cmd': 'mlrun get run c254cab12e9c447190295db829ca58e2 -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs c254cab12e9c447190295db829ca58e2 -p learn-docs-dev-admin'}
# > 2023-05-07 11:03:52,567 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/c254cab12e9c447190295db829ca58e2/overview'}
# > 2023-05-07 11:03:52,567 [info] run executed, status=running: {'name': 'trainer'}
# > 2023-05-07 11:03:52,576 [info] To track results use the CLI: {'info_cmd': 'mlrun get run c254cab12e9c447190295db829ca58e2 -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs c254cab12e9c447190295db829ca58e2 -p learn-docs-dev-admin'}
# > 2023-05-07 11:03:52,577 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/c254cab12e9c447190295db829ca58e2/overview'}
# > 2023-05-07 11:03:52,577 [info] run executed, status=running: {'name': 'trainer'}
# > 2023-05-07 11:03:54,265 [info] To track results use the CLI: {'info_cmd': 'mlrun get run c254cab12e9c447190295db829ca58e2 -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs c254cab12e9c447190295db829ca58e2 -p learn-docs-dev-admin'}
# > 2023-05-07 11:03:54,265 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/c254cab12e9c447190295db829ca58e2/overview'}
# > 2023-05-07 11:03:54,266 [info] run executed, status=running: {'name': 'trainer'}
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>learn-docs-dev-admin</td>
#       <td><div title="c254cab12e9c447190295db829ca58e2"><a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/c254cab12e9c447190295db829ca58e2/overview" target="_blank" >...29ca58e2</a></div></td>
#       <td>0</td>
#       <td>May 07 11:01:36</td>
#       <td>completed</td>
#       <td>trainer</td>
#       <td><div class="dictlist">v3io_user=admin</div><div class="dictlist">kind=mpijob</div><div class="dictlist">owner=admin</div><div class="dictlist">mlrun/client_version=1.3.0</div><div class="dictlist">mlrun/client_python_version=3.9.16</div><div class="dictlist">mlrun/job=trainer-f8a2010b</div><div class="dictlist">host=trainer-f8a2010b-worker-0</div></td>
#       <td><div title="store://datasets/deepspeed-admin/data-prep-prepare-dataset_train_dataset#0:latest">dataset</div><div title="store://datasets/deepspeed-admin/data-prep-prepare-dataset_test_dataset#0:latest">test_set</div></td>
#       <td><div class="dictlist">model_name=gpt2-ft-mlrun</div><div class="dictlist">pretrained_model=gpt2</div><div class="dictlist">pretrained_tokenizer=gpt2</div><div class="dictlist">model_class=transformers.GPT2LMHeadModel</div><div class="dictlist">tokenizer_class=transformers.GPT2Tokenizer</div><div class="dictlist">random_state=42</div><div class="dictlist">TRAIN_output_dir=/User/learn-docs/finetuning-mlrun-data</div><div class="dictlist">TRAIN_overwrite_output_dir=True</div><div class="dictlist">TRAIN_num_train_epochs=2</div><div class="dictlist">TRAIN_fp16=True</div><div class="dictlist">TRAIN_bf16=False</div><div class="dictlist">TRAIN_per_device_train_batch_size=4</div><div class="dictlist">TRAIN_per_device_eval_batch_size=4</div><div class="dictlist">TRAIN_save_steps=10000</div><div class="dictlist">TRAIN_save_total_limit=2</div><div class="dictlist">TRAIN_deepspeed=/User/learn-docs/deepspeed_config/stage3.json</div></td>
#       <td><div class="dictlist">train_runtime=16.752</div><div class="dictlist">train_samples_per_second=16.118</div><div class="dictlist">train_steps_per_second=1.075</div><div class="dictlist">total_flos=190381457408.0</div><div class="dictlist">train_loss=2.9049479166666665</div></td>
#       <td><div title="v3io:///projects/learn-docs-dev-admin/artifacts/trainer/0/tokenizer.zip">tokenizer</div><div title="v3io:///projects/learn-docs-dev-admin/artifacts/trainer/0/model/">model</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="resultc07fa4a6-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="resultc07fa4a6-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="resultc07fa4a6" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="resultc07fa4a6-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/c254cab12e9c447190295db829ca58e2/overview" target="_blank">click here</a> to open in UI</b>
# > 2023-05-07 11:04:34,780 [info] run executed, status=completed: {'name': 'trainer'}

# %% [markdown]
# ### Test our fine-tuned model

# %%
model_name = "store://models/deepspeed-admin/gpt2-ft-mlrun#0:latest"
tokenizer_name = "store://artifacts/deepspeed-admin/trainer_tokenizer#0:latest"

# %%
temp_model = os.path.join(base_path, "finetuning-mlrun-data")

# %%
mlrun.run_function(function="test-llm", params={"model_name": "gpt2"})
# Out:
# > 2023-05-07 09:34:08,918 [info] Storing function: {'name': 'test-llm-load-my-model', 'uid': '9dd0a9d8dd634797a6e3779115cbdcec', 'db': 'http://mlrun-api:8080'}
# > 2023-05-07 09:34:09,167 [info] Job is running in the background, pod: test-llm-load-my-model-xjzwf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 mlrun.run_function(function="test-llm", params={"model_name": "gpt2"})
#
# File /conda/envs/mlrun-base/lib/python3.9/site-packages/mlrun/projects/operations.py:187, in run_function(function, handler, name, params, hyperparams, hyper_param_options, inputs, outputs, workdir, labels, base_task, watch, local, verbose, selector, project_object, auto_build, schedule, artifact_path, returns)
#     185 if local and project and function.spec.build.source:
#     186     workdir = workdir or project.spec.get_code_path()
# --> 187 run_result = function.run(
#     188     name=name,
#     189     runspec=task,
#     190     workdir=workdir,
#     191     verbose=verbose,
#     192     watch=watch,
#     193     local=local,
#     194     artifact_path=artifact_path
#     195     # workflow artifact_path has precedence over the project artifact_path equivalent to
#     196     # passing artifact_path to function.run() has precedence over the project.artifact_path and the default one
#     197     or pipeline_context.workflow_artifact_path
#     198     or (project.artifact_path if project else None),
#     199     auto_build=auto_build,
#     200     schedule=schedule,
#     201 )
#     202 if run_result:
#     203     run_result._notified = False
#
# File /conda/envs/mlrun-base/lib/python3.9/site-packages/mlrun/runtimes/base.py:467, in BaseRuntime.run(self, runspec, handler, name, project, params, inputs, out_path, workdir, artifact_path, watch, schedule, hyperparams, hyper_param_options, verbose, scrape_metrics, local, local_code_path, auto_build, param_file_secrets, returns)
#     465 # execute the job remotely (to a k8s cluster via the API service)
#     466 if self._use_remote_api():
# --> 467     return self._submit_job(run, schedule, db, watch)
#     469 elif self._is_remote and not self._is_api_server and not self.kfp:
#     470     logger.warning(
#     471         "warning!, Api url not set, " "trying to exec remote runtime locally"
#     472     )
#
# File /conda/envs/mlrun-base/lib/python3.9/site-packages/mlrun/runtimes/base.py:842, in BaseRuntime._submit_job(self, run, schedule, db, watch)
#     839     resp = self._get_db_run(run)
#     841 elif watch or self.kfp:
# --> 842     run.logs(True, self._get_db())
#     843     resp = self._get_db_run(run)
#     845 return self._wrap_run_result(resp, run, schedule=schedule)
#
# File /conda/envs/mlrun-base/lib/python3.9/site-packages/mlrun/model.py:1079, in RunObject.logs(self, watch, db, offset)
#    1077 new_offset = 0
#    1078 if db.kind == "http":
# -> 1079     state, new_offset = db.watch_log(
#    1080         self.metadata.uid, self.metadata.project, watch=watch, offset=offset
#    1081     )
#    1082 # not expected to reach this else, as FileDB is not supported any more and because we don't watch logs on API
#    1083 else:
#    1084     state, text = db.get_log(
#    1085         self.metadata.uid, self.metadata.project, offset=offset
#    1086     )
#
# File /conda/envs/mlrun-base/lib/python3.9/site-packages/mlrun/db/httpdb.py:471, in HTTPRunDB.watch_log(self, uid, project, watch, offset)
#     468 # if we get 3 nil responses in a row, increase the sleep time to 10 seconds
#     469 # TODO: refactor this to use a conditional backoff mechanism
#     470 if nil_resp < 3:
# --> 471     time.sleep(int(mlrun.mlconf.httpdb.logs.pull_logs_default_interval))
#     472 else:
#     473     time.sleep(
#     474         int(
#     475             mlrun.mlconf.httpdb.logs.pull_logs_backoff_no_logs_default_interval
#     476         )
#     477     )
#
# KeyboardInterrupt:

# %% [markdown]
# ## Train on DataBricks Dolly dataset

# %%
prepare_dolly_dataset = project.set_function(
    "src/data_prep_dolly.py",
    name="data-prep-dolly",
    handler="preprocess_dolly",
    kind="job",
)
prepare_dolly_dataset.apply(mlrun.auto_mount())

# %%
prepare_dolly_run = mlrun.run_function(
    function="data-prep-dolly",
    params={"pretrained_tokenizer_name_or_path": "gpt2"},
    handler="preprocess_dolly",
)
# Out:
# > 2023-05-07 09:34:25,375 [info] Storing function: {'name': 'data-prep-dolly-preprocess-dolly', 'uid': 'd9a282660b304544bbcf86c3c19fee25', 'db': 'http://mlrun-api:8080'}
# > 2023-05-07 09:34:25,510 [info] Job is running in the background, pod: data-prep-dolly-preprocess-dolly-pcjfp
# > 2023-05-07 09:34:42,739 [info] Loading tokenizer for gpt2
# Downloading (…)lve/main/config.json: 100%|██████████| 665/665 [00:00<00:00, 93.8kB/s]
# Downloading (…)olve/main/vocab.json: 100%|██████████| 1.04M/1.04M [00:00<00:00, 20.4MB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 6.04MB/s]
# Downloading (…)/main/tokenizer.json: 100%|██████████| 1.36M/1.36M [00:00<00:00, 22.5MB/s]
# > 2023-05-07 09:34:43,680 [info] Loading dataset from databricks/databricks-dolly-15k
# Downloading readme: 100%|██████████| 7.70k/7.70k [00:00<00:00, 7.47MB/s]
# Downloading and preparing dataset json/databricks--databricks-dolly-15k to /root/.cache/huggingface/datasets/databricks___json/databricks--databricks-dolly-15k-6e0f9ea7eaa0ee08/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/13.1M [00:00<?, ?B/s]
# Downloading data: 100%|██████████| 13.1M/13.1M [00:00<00:00, 104MB/s]
# Downloading data files: 100%|██████████| 1/1 [00:00<00:00,  3.69it/s]
# Extracting data files: 100%|██████████| 1/1 [00:00<00:00, 1554.60it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/databricks___json/databricks--databricks-dolly-15k-6e0f9ea7eaa0ee08/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4. Subsequent calls will reuse this data.
# 100%|██████████| 1/1 [00:00<00:00, 226.80it/s]
# > 2023-05-07 09:34:44,611 [info] Found 15011 rows
# > 2023-05-07 09:34:45,586 [info] Preprocessing dataset
# > 2023-05-07 09:34:50,802 [info] Processed dataset has 15011 rows
# > 2023-05-07 09:34:52,858 [info] Processed dataset has 14812 rows after filtering for truncated records
# > 2023-05-07 09:34:52,858 [info] Shuffling dataset
# > 2023-05-07 09:34:52,867 [info] Done preprocessing
# > 2023-05-07 09:34:52,873 [info] Train data size: 13812
# > 2023-05-07 09:34:52,873 [info] Test data size: 1000
# > 2023-05-07 09:35:25,180 [info] To track results use the CLI: {'info_cmd': 'mlrun get run d9a282660b304544bbcf86c3c19fee25 -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs d9a282660b304544bbcf86c3c19fee25 -p learn-docs-dev-admin'}
# > 2023-05-07 09:35:25,180 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/d9a282660b304544bbcf86c3c19fee25/overview'}
# > 2023-05-07 09:35:25,180 [info] run executed, status=completed: {'name': 'data-prep-dolly-preprocess-dolly'}
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>learn-docs-dev-admin</td>
#       <td><div title="d9a282660b304544bbcf86c3c19fee25"><a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/d9a282660b304544bbcf86c3c19fee25/overview" target="_blank" >...c19fee25</a></div></td>
#       <td>0</td>
#       <td>May 07 09:34:41</td>
#       <td>completed</td>
#       <td>data-prep-dolly-preprocess-dolly</td>
#       <td><div class="dictlist">v3io_user=admin</div><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div><div class="dictlist">mlrun/client_version=1.3.0</div><div class="dictlist">mlrun/client_python_version=3.9.16</div><div class="dictlist">host=data-prep-dolly-preprocess-dolly-pcjfp</div></td>
#       <td></td>
#       <td><div class="dictlist">pretrained_tokenizer_name_or_path=gpt2</div></td>
#       <td></td>
#       <td><div title="v3io:///projects/learn-docs-dev-admin/artifacts/data-prep-dolly-preprocess-dolly/0/train_dolly_dataset.parquet">train_dolly_dataset</div><div title="v3io:///projects/learn-docs-dev-admin/artifacts/data-prep-dolly-preprocess-dolly/0/test_dolly_dataset.parquet">test_dolly_dataset</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result0666344e-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result0666344e-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result0666344e" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result0666344e-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/d9a282660b304544bbcf86c3c19fee25/overview" target="_blank">click here</a> to open in UI</b>
# > 2023-05-07 09:35:33,977 [info] run executed, status=completed: {'name': 'data-prep-dolly-preprocess-dolly'}

# %%
prepare_dolly_run.outputs
# Out:
# {'train_dolly_dataset': 'store://artifacts/learn-docs-dev-admin/data-prep-dolly-preprocess-dolly_train_dolly_dataset:d9a282660b304544bbcf86c3c19fee25',
#  'test_dolly_dataset': 'store://artifacts/learn-docs-dev-admin/data-prep-dolly-preprocess-dolly_test_dolly_dataset:d9a282660b304544bbcf86c3c19fee25'}

# %%
train_dolly_dataset = "store://artifacts/learn-docs-dev-admin/data-prep-dolly-preprocess-dolly_train_dolly_dataset:d9a282660b304544bbcf86c3c19fee25"
test_dolly_dataset = "store://artifacts/learn-docs-dev-admin/data-prep-dolly-preprocess-dolly_test_dolly_dataset:d9a282660b304544bbcf86c3c19fee25"

# %%
params= {
    "pretrained_model": temp_model,
    "pretrained_tokenizer": temp_model,
    "model_class": "transformers.AutoModelForCausalLM",
    "tokenizer_class": "transformers.AutoTokenizer",
    "require_tokenization": False,
    "TRAIN_deepspeed": os.path.join(base_path, "deepspeed_config/ds_z3_bf16_config.json"),
    "TRAIN_num_train_epochs": 2,
    "TRAIN_output_dir": "dolly_output",
    "TRAIN_per_device_train_batch_size": 6,
    "TRAIN_per_device_eval_batch_size": 6,
    "TRAIN_logging_steps": 10,
    "TRAIN_save_steps": 200,
    "TRAIN_save_total_limit": 20,
    "TRAIN_eval_steps": 50,
    "TRAIN_warmup_steps": 50,
    "TRAIN_learning_rate": 5e-6,
    "TRAIN_gradient_checkpointing": True,
    "TRAIN_local_rank": True,
    "TRAIN_bf16": False,
    "CLASS_ignore_mismatched_sizes": True,
    "data_collator": "src.data_collator.DataCollatorForCompletionOnlyLM",
    "DC_mlm": False,
    "DC_return_tensors": "pt",
    "pad_to_multiple_of": 8,
    
}

# %%
 mlrun.run_function(
    function="hugging_face_classifier_trainer",
    name="trainer",
    inputs={
            "dataset": train_dolly_dataset,  # prepare_dolly_run.outputs["train_dolly_dataset"],
            "test_set": test_dataset  # prepare_dolly_run.outputs["test_dolly_dataset"],
        },
    params=params,
    handler="train",
)

# %% [markdown]
# ### Test complete model
