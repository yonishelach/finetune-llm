# %% [markdown]
# # Fine-tuning LLM on MLRun documentation

# %%
import mlrun
import os

# %%
# TODO: Create project with better name:
project = mlrun.get_or_create_project("learn-docs-dev", user_project=True)
# TODO: Change to more exact image with appropiate tag:
project.set_default_image("yonishelach/mlrun:ds-debug-u")
# Out:
# > 2023-05-07 05:04:52,844 [info] Created and saved project learn-docs-dev-admin: {'from_template': None, 'overwrite': False, 'context': './', 'save': True}
# > 2023-05-07 05:04:52,846 [info] created project learn-docs-dev and saved in MLRun DB

# %%
base_path = os.path.abspath(project.context)
base_path
# Out:
# '/User/learn-docs'

# %% [markdown]
# ## Prepare MLRun documentation data

# %% [markdown]
# ### Download docs

# %%
fetch_docs = project.set_function(
    "src/download_docs.py",
    name="docs-downloader",
    handler="download_all_files",
    kind="job",
)
fetch_docs.apply(mlrun.auto_mount())

# %%
target_dir = os.path.join(base_path, "data/mlrun_docs")
# url = 'https://pandas.pydata.org/docs/user_guide/'
url = 'https://docs.mlrun.org/en/stable/'

# %%
fetch_docs_run = mlrun.run_function(
    function="docs-downloader",
    params={"target_dir": target_dir, "url": url},
    outputs=["docs_dir"],
)
# Out:
# > 2023-05-07 06:20:53,643 [info] Storing function: {'name': 'docs-downloader-download-all-files', 'uid': 'd4ff024cf5e340739e006ce9139bee7c', 'db': 'http://mlrun-api:8080'}
# > 2023-05-07 06:20:53,893 [info] Job is running in the background, pod: docs-downloader-download-all-files-nd86b
# Found 127 links in https://docs.mlrun.org/en/stable/
# wrote file: /User/learn-docs/data/mlrun_docs/architecture.html
# wrote file: /User/learn-docs/data/mlrun_docs/tutorial_04-pipeline.html
# wrote file: /User/learn-docs/data/mlrun_docs/install_local-docker.html
# wrote file: /User/learn-docs/data/mlrun_docs/install_remote.html
# wrote file: /User/learn-docs/data/mlrun_docs/projects_project.html
# wrote file: /User/learn-docs/data/mlrun_docs/install_aws-install.html
# wrote file: /User/learn-docs/data/mlrun_docs/projects_load-project.html
# wrote file: /User/learn-docs/data/mlrun_docs/tutorial_index.html
# wrote file: /User/learn-docs/data/mlrun_docs/projects_ci-integration.html
# wrote file: /User/learn-docs/data/mlrun_docs/secrets.html
# wrote file: /User/learn-docs/data/mlrun_docs/runtimes_functions.html
# wrote file: /User/learn-docs/data/mlrun_docs/tutorial_03-model-serving.html
# wrote file: /User/learn-docs/data/mlrun_docs/runtimes_dask-overview.html
# wrote file: /User/learn-docs/data/mlrun_docs/tutorial_07-batch-infer.html
# wrote file: /User/learn-docs/data/mlrun_docs/install_kubernetes.html
# wrote file: /User/learn-docs/data/mlrun_docs/runtimes_horovod.html
# wrote file: /User/learn-docs/data/mlrun_docs/concepts_nuclio-real-time-functions.html
# wrote file: /User/learn-docs/data/mlrun_docs/projects_create-project.html
# wrote file: /User/learn-docs/data/mlrun_docs/runtimes_functions-architecture.html
# wrote file: /User/learn-docs/data/mlrun_docs/feature-store_basic-demo.html
# wrote file: /User/learn-docs/data/mlrun_docs/runtimes_function-storage.html
# wrote file: /User/learn-docs/data/mlrun_docs/concepts_functions-overview.html
# wrote file: /User/learn-docs/data/mlrun_docs/runtimes_create-and-use-functions.html
# wrote file: /User/learn-docs/data/mlrun_docs/runtimes_dask-mlrun.html
# wrote file: /User/learn-docs/data/mlrun_docs/runtimes_image-build.html
# wrote file: /User/learn-docs/data/mlrun_docs/projects_run-build-deploy.html
# wrote file: /User/learn-docs/data/mlrun_docs/runtimes_configuring-job-resources.html
# wrote file: /User/learn-docs/data/mlrun_docs/concepts_data.html
# wrote file: /User/learn-docs/data/mlrun_docs/store_data-items.html
# wrote file: /User/learn-docs/data/mlrun_docs/feature-store_transformations.html
# wrote file: /User/learn-docs/data/mlrun_docs/runtimes_mlrun_code_annotations.html
# wrote file: /User/learn-docs/data/mlrun_docs/store_artifacts.html
# wrote file: /User/learn-docs/data/mlrun_docs/runtimes_load-from-hub.html
# wrote file: /User/learn-docs/data/mlrun_docs/feature-store_feature-sets.html
# wrote file: /User/learn-docs/data/mlrun_docs/feature-store_feature-store-overview.html
# wrote file: /User/learn-docs/data/mlrun_docs/store_models.html
# wrote file: /User/learn-docs/data/mlrun_docs/feature-store_end-to-end-demo_02-create-training-model.html
# wrote file: /User/learn-docs/data/mlrun_docs/feature-store_end-to-end-demo_index.html
# wrote file: /User/learn-docs/data/mlrun_docs/feature-store_feature-vectors.html
# wrote file: /User/learn-docs/data/mlrun_docs/concepts_decorators-and-auto-logging.html
# wrote file: /User/learn-docs/data/mlrun_docs/concepts_workflow-overview.html
# wrote file: /User/learn-docs/data/mlrun_docs/feature-store_end-to-end-demo_03-deploy-serving-model.html
# wrote file: /User/learn-docs/data/mlrun_docs/feature-store_end-to-end-demo_01-ingest-datasources.html
# wrote file: /User/learn-docs/data/mlrun_docs/tutorial_02-model-training.html
# wrote file: /User/learn-docs/data/mlrun_docs/tutorial_06-add-mlops-to-code.html
# wrote file: /User/learn-docs/data/mlrun_docs/concepts_mlrun-execution-context.html
# wrote file: /User/learn-docs/data/mlrun_docs/feature-store_end-to-end-demo_04-pipeline.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_getting-started.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_use-cases.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_serving-graph.html
# wrote file: /User/learn-docs/data/mlrun_docs/concepts_runs-workflows.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_writing-custom-steps.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_available-steps.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_distributed-graph.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_graph-example.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_graph-ha-cfg.html
# wrote file: /User/learn-docs/data/mlrun_docs/concepts_scheduled-jobs.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_pipelines-error-handling.html
# wrote file: /User/learn-docs/data/mlrun_docs/data-prep_ingesting_data.html
# wrote file: /User/learn-docs/data/mlrun_docs/data-prep_ingest-data-fs.html
# wrote file: /User/learn-docs/data/mlrun_docs/concepts_monitoring.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_model-serving-get-started.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_demos.html
# wrote file: /User/learn-docs/data/mlrun_docs/development_model-training-tracking.html
# wrote file: /User/learn-docs/data/mlrun_docs/training_working-with-data-and-model-artifacts.html
# wrote file: /User/learn-docs/data/mlrun_docs/development_index.html
# wrote file: /User/learn-docs/data/mlrun_docs/training_built-in-training-function.html
# wrote file: /User/learn-docs/data/mlrun_docs/feature-store_using-spark-engine.html
# wrote file: /User/learn-docs/data/mlrun_docs/hyper-params.html
# wrote file: /User/learn-docs/data/mlrun_docs/deployment_index.html
# wrote file: /User/learn-docs/data/mlrun_docs/data-prep_logging_datasets.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_serving-overview.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_built-in-model-serving.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_test-deploy-model-server.html
# wrote file: /User/learn-docs/data/mlrun_docs/feature-store_retrieve-offline-data.html
# wrote file: /User/learn-docs/data/mlrun_docs/training_create-a-basic-training-job.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_model-api.html
# wrote file: /User/learn-docs/data/mlrun_docs/deployment_batch_inference.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_canary.html
# wrote file: /User/learn-docs/data/mlrun_docs/monitoring_model-monitoring-deployment.html
# wrote file: /User/learn-docs/data/mlrun_docs/monitoring_initial-setup-configuration.html
# wrote file: /User/learn-docs/data/mlrun_docs/genindex.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_index.html
# wrote file: /User/learn-docs/data/mlrun_docs/monitoring_index.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.frameworks_mlrun.frameworks.tf_keras.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.frameworks_mlrun.frameworks.pytorch.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.frameworks_mlrun.frameworks.sklearn.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.frameworks_mlrun.frameworks.xgboost.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.frameworks_mlrun.frameworks.lgbm.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.artifacts.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.config.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.datastore.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.db.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.execution.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.feature_store.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.model.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.platforms.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.projects.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.run.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.runtimes.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.serving.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_storey.transformations.html
# wrote file: /User/learn-docs/data/mlrun_docs/cli.html
# wrote file: /User/learn-docs/data/mlrun_docs/glossary.html
# wrote file: /User/learn-docs/data/mlrun_docs/install.html
# wrote file: /User/learn-docs/data/mlrun_docs/tutorial_01-mlrun-basics.html
# wrote file: /User/learn-docs/data/mlrun_docs/mlops-dev-flow.html
# wrote file: /User/learn-docs/data/mlrun_docs/projects_build-run-workflows-pipelines.html
# wrote file: /User/learn-docs/data/mlrun_docs/tutorial_05-model-monitoring.html
# wrote file: /User/learn-docs/data/mlrun_docs/contents.html
# wrote file: /User/learn-docs/data/mlrun_docs/runtimes_spark-operator.html
# wrote file: /User/learn-docs/data/mlrun_docs/feature-store_feature-store.html
# wrote file: /User/learn-docs/data/mlrun_docs/concepts_node-affinity.html
# wrote file: /User/learn-docs/data/mlrun_docs/runtimes_dask-pipeline.html
# wrote file: /User/learn-docs/data/mlrun_docs/store_datastore.html
# wrote file: /User/learn-docs/data/mlrun_docs/runtimes_images.html
# wrote file: /User/learn-docs/data/mlrun_docs/concepts_submitting-tasks-jobs-to-functions.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_realtime-pipelines.html
# wrote file: /User/learn-docs/data/mlrun_docs/data-prep_index.html
# wrote file: /User/learn-docs/data/mlrun_docs/concepts_auto-logging-mlops.html
# wrote file: /User/learn-docs/data/mlrun_docs/serving_custom-model-serving-class.html
# wrote file: /User/learn-docs/data/mlrun_docs/feature-store_training-serving.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.frameworks_index.html
# wrote file: /User/learn-docs/data/mlrun_docs/api_mlrun.frameworks_mlrun.frameworks.auto_mlrun.html
# > 2023-05-07 06:21:19,644 [info] To track results use the CLI: {'info_cmd': 'mlrun get run d4ff024cf5e340739e006ce9139bee7c -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs d4ff024cf5e340739e006ce9139bee7c -p learn-docs-dev-admin'}
# > 2023-05-07 06:21:19,644 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/d4ff024cf5e340739e006ce9139bee7c/overview'}
# > 2023-05-07 06:21:19,645 [info] run executed, status=completed: {'name': 'docs-downloader-download-all-files'}
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>learn-docs-dev-admin</td>
#       <td><div title="d4ff024cf5e340739e006ce9139bee7c"><a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/d4ff024cf5e340739e006ce9139bee7c/overview" target="_blank" >...139bee7c</a></div></td>
#       <td>0</td>
#       <td>May 07 06:21:09</td>
#       <td>completed</td>
#       <td>docs-downloader-download-all-files</td>
#       <td><div class="dictlist">v3io_user=admin</div><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div><div class="dictlist">mlrun/client_version=1.3.0</div><div class="dictlist">mlrun/client_python_version=3.9.16</div><div class="dictlist">host=docs-downloader-download-all-files-nd86b</div></td>
#       <td></td>
#       <td><div class="dictlist">target_dir=/User/learn-docs/data/mlrun_docs</div><div class="dictlist">url=https://docs.mlrun.org/en/stable/</div></td>
#       <td></td>
#       <td><div title="v3io:///projects/learn-docs-dev-admin/artifacts/docs-downloader-download-all-files/0/docs_dir.zip">docs_dir</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result2f4cfdde-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result2f4cfdde-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result2f4cfdde" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result2f4cfdde-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/d4ff024cf5e340739e006ce9139bee7c/overview" target="_blank">click here</a> to open in UI</b>
# > 2023-05-07 06:21:21,107 [info] run executed, status=completed: {'name': 'docs-downloader-download-all-files'}

# %%
fetch_docs_run.outputs["docs_dir"]
# Out:
# 'v3io:///projects/learn-docs-dev-admin/artifacts/docs-downloader-download-all-files/0/docs_dir.zip'

# %%
docs_dir = 'v3io:///projects/learn-docs-dev-admin/artifacts/docs-downloader-download-all-files/0/docs_dir.zip'

# %% [markdown]
# ### Prepare docs dataset

# %%
data_preparation = project.set_function(
    "src/data_prep.py",
    name="data-prep",
    handler="prepare_dataset",
    kind="job",
)
data_preparation.apply(mlrun.auto_mount())

# %%
target_dir = os.path.join(base_path, "data/mlrun_dataset")
prepare_dataset_run = mlrun.run_function(
    function="data-prep",
    params={
        "target_dir": target_dir,
        "ignored_files": ["contents", "genindex"],
    },
    inputs={"docs_source": docs_dir},
    outputs=["train_dataset", "test_dataset", "additional_params"],
)
# Out:
# > 2023-05-07 06:21:21,259 [info] Storing function: {'name': 'data-prep-prepare-dataset', 'uid': '4275bc1e3c8845eb9871d8330ad5a2fa', 'db': 'http://mlrun-api:8080'}
# > 2023-05-07 06:21:21,499 [info] Job is running in the background, pod: data-prep-prepare-dataset-l7w72
# Added to dataset: api_index
# Added to dataset: api_mlrun.artifacts
# Added to dataset: api_mlrun.config
# Added to dataset: api_mlrun.datastore
# Added to dataset: api_mlrun.db
# Added to dataset: api_mlrun.execution
# Added to dataset: api_mlrun.feature_store
# Added to dataset: api_mlrun.frameworks_index
# Added to dataset: api_mlrun.frameworks_mlrun.frameworks.auto_mlrun
# Added to dataset: api_mlrun.frameworks_mlrun.frameworks.lgbm
# Added to dataset: api_mlrun.frameworks_mlrun.frameworks.pytorch
# Added to dataset: api_mlrun.frameworks_mlrun.frameworks.sklearn
# Added to dataset: api_mlrun.frameworks_mlrun.frameworks.tf_keras
# Added to dataset: api_mlrun.frameworks_mlrun.frameworks.xgboost
# Added to dataset: api_mlrun
# Added to dataset: api_mlrun.model
# Added to dataset: api_mlrun.platforms
# Added to dataset: api_mlrun.projects
# Added to dataset: api_mlrun.run
# Added to dataset: api_mlrun.runtimes
# Added to dataset: api_mlrun.serving
# Added to dataset: api_storey.transformations
# Added to dataset: architecture
# Added to dataset: cli
# Added to dataset: concepts_auto-logging-mlops
# Added to dataset: concepts_data
# Added to dataset: concepts_decorators-and-auto-logging
# Added to dataset: concepts_functions-overview
# Added to dataset: concepts_mlrun-execution-context
# Added to dataset: concepts_monitoring
# Added to dataset: concepts_node-affinity
# Added to dataset: concepts_nuclio-real-time-functions
# Added to dataset: concepts_runs-workflows
# Added to dataset: concepts_scheduled-jobs
# Added to dataset: concepts_submitting-tasks-jobs-to-functions
# Added to dataset: concepts_workflow-overview
# Added to dataset: data-prep_index
# Added to dataset: data-prep_ingest-data-fs
# Added to dataset: data-prep_ingesting_data
# Added to dataset: data-prep_logging_datasets
# Added to dataset: deployment_batch_inference
# Added to dataset: deployment_index
# Added to dataset: development_index
# Added to dataset: development_model-training-tracking
# Added to dataset: feature-store_basic-demo
# Added to dataset: feature-store_end-to-end-demo_01-ingest-datasources
# Added to dataset: feature-store_end-to-end-demo_02-create-training-model
# Added to dataset: feature-store_end-to-end-demo_03-deploy-serving-model
# Added to dataset: feature-store_end-to-end-demo_04-pipeline
# Added to dataset: feature-store_end-to-end-demo_index
# Added to dataset: feature-store_feature-sets
# Added to dataset: feature-store_feature-store-overview
# Added to dataset: feature-store_feature-store
# Added to dataset: feature-store_feature-vectors
# Added to dataset: feature-store_retrieve-offline-data
# Added to dataset: feature-store_training-serving
# Added to dataset: feature-store_transformations
# Added to dataset: feature-store_using-spark-engine
# Added to dataset: glossary
# Added to dataset: hyper-params
# Added to dataset: install
# Added to dataset: install_aws-install
# Added to dataset: install_kubernetes
# Added to dataset: install_local-docker
# Added to dataset: install_remote
# Added to dataset: mlops-dev-flow
# Added to dataset: monitoring_index
# Added to dataset: monitoring_initial-setup-configuration
# Added to dataset: monitoring_model-monitoring-deployment
# Added to dataset: projects_build-run-workflows-pipelines
# Added to dataset: projects_ci-integration
# Added to dataset: projects_create-project
# Added to dataset: projects_load-project
# Added to dataset: projects_project
# Added to dataset: projects_run-build-deploy
# Added to dataset: runtimes_configuring-job-resources
# Added to dataset: runtimes_create-and-use-functions
# Added to dataset: runtimes_dask-mlrun
# Added to dataset: runtimes_dask-overview
# Added to dataset: runtimes_dask-pipeline
# Added to dataset: runtimes_function-storage
# Added to dataset: runtimes_functions-architecture
# Added to dataset: runtimes_functions
# Added to dataset: runtimes_horovod
# Added to dataset: runtimes_images
# Added to dataset: runtimes_image-build
# Added to dataset: runtimes_load-from-hub
# Added to dataset: runtimes_mlrun_code_annotations
# Added to dataset: runtimes_spark-operator
# Added to dataset: secrets
# Added to dataset: serving_available-steps
# Added to dataset: serving_built-in-model-serving
# Added to dataset: serving_canary
# Added to dataset: serving_custom-model-serving-class
# Added to dataset: serving_demos
# Added to dataset: serving_distributed-graph
# Added to dataset: serving_getting-started
# Added to dataset: serving_graph-example
# Added to dataset: serving_graph-ha-cfg
# Added to dataset: serving_model-api
# Added to dataset: serving_model-serving-get-started
# Added to dataset: serving_pipelines-error-handling
# Added to dataset: serving_realtime-pipelines
# Added to dataset: serving_serving-graph
# Added to dataset: serving_serving-overview
# Added to dataset: serving_test-deploy-model-server
# Added to dataset: serving_use-cases
# Added to dataset: serving_writing-custom-steps
# Added to dataset: store_artifacts
# Added to dataset: store_data-items
# Added to dataset: store_datastore
# Added to dataset: store_models
# Added to dataset: training_built-in-training-function
# Added to dataset: training_create-a-basic-training-job
# Added to dataset: training_working-with-data-and-model-artifacts
# Added to dataset: tutorial_01-mlrun-basics
# Added to dataset: tutorial_02-model-training
# Added to dataset: tutorial_03-model-serving
# Added to dataset: tutorial_04-pipeline
# Added to dataset: tutorial_05-model-monitoring
# Added to dataset: tutorial_06-add-mlops-to-code
# Added to dataset: tutorial_07-batch-infer
# Added to dataset: tutorial_index
# ===== Ignored files: =====
# /tmp/tmpllzkglyx/contents.html
# /tmp/tmpllzkglyx/genindex.html
# Downloading and preparing dataset json/mlrun_dataset to /root/.cache/huggingface/datasets/json/mlrun_dataset-1cf39e3d8724db3e/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4...
# Downloading data files: 100%|██████████| 1/1 [00:00<00:00, 2179.99it/s]
# Extracting data files: 100%|██████████| 1/1 [00:00<00:00, 110.51it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/mlrun_dataset-1cf39e3d8724db3e/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4. Subsequent calls will reuse this data.
# 100%|██████████| 1/1 [00:00<00:00, 832.70it/s]
# > 2023-05-07 06:21:49,657 [info] To track results use the CLI: {'info_cmd': 'mlrun get run 4275bc1e3c8845eb9871d8330ad5a2fa -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs 4275bc1e3c8845eb9871d8330ad5a2fa -p learn-docs-dev-admin'}
# > 2023-05-07 06:21:49,657 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/4275bc1e3c8845eb9871d8330ad5a2fa/overview'}
# > 2023-05-07 06:21:49,658 [info] run executed, status=completed: {'name': 'data-prep-prepare-dataset'}
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>learn-docs-dev-admin</td>
#       <td><div title="4275bc1e3c8845eb9871d8330ad5a2fa"><a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/4275bc1e3c8845eb9871d8330ad5a2fa/overview" target="_blank" >...0ad5a2fa</a></div></td>
#       <td>0</td>
#       <td>May 07 06:21:36</td>
#       <td>completed</td>
#       <td>data-prep-prepare-dataset</td>
#       <td><div class="dictlist">v3io_user=admin</div><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div><div class="dictlist">mlrun/client_version=1.3.0</div><div class="dictlist">mlrun/client_python_version=3.9.16</div><div class="dictlist">host=data-prep-prepare-dataset-l7w72</div></td>
#       <td><div title="v3io:///projects/learn-docs-dev-admin/artifacts/docs-downloader-download-all-files/0/docs_dir.zip">docs_source</div></td>
#       <td><div class="dictlist">target_dir=/User/learn-docs/data/mlrun_dataset</div><div class="dictlist">ignored_files=['contents', 'genindex']</div></td>
#       <td></td>
#       <td><div title="v3io:///projects/learn-docs-dev-admin/artifacts/data-prep-prepare-dataset/0/train_dataset.parquet">train_dataset</div><div title="v3io:///projects/learn-docs-dev-admin/artifacts/data-prep-prepare-dataset/0/test_dataset.parquet">test_dataset</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="resultedd6cb95-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="resultedd6cb95-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="resultedd6cb95" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="resultedd6cb95-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/4275bc1e3c8845eb9871d8330ad5a2fa/overview" target="_blank">click here</a> to open in UI</b>
# > 2023-05-07 06:21:55,708 [info] run executed, status=completed: {'name': 'data-prep-prepare-dataset'}

# %%
train_dataset = "store://datasets/deepspeed-admin/data-prep-prepare-dataset_train_dataset#0:latest"
test_dataset = "store://datasets/deepspeed-admin/data-prep-prepare-dataset_test_dataset#0:latest"

# %% [markdown]
# ## Test pretrained LLM from HuggingFace hub without fine-tuning

# %%
test_pretrained_llm = project.set_function(
    "src/test_model.py",
    name="test-llm",
    handler="load_my_model",
    kind="job",
)
test_pretrained_llm.apply(mlrun.auto_mount())

# %%
mlrun.run_function(function="test-llm", params={"model_name": "gpt2"})
# Out:
# > 2023-05-07 06:25:02,457 [info] Storing function: {'name': 'test-llm-load-my-model', 'uid': '4966edac55d34337aa7e345c8c2fe00b', 'db': 'http://mlrun-api:8080'}
# > 2023-05-07 06:25:02,706 [info] Job is running in the background, pod: test-llm-load-my-model-flhbm
# Downloading (…)olve/main/vocab.json: 100%|██████████| 1.04M/1.04M [00:00<00:00, 27.9MB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 11.9MB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 665/665 [00:00<00:00, 407kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 548M/548M [00:01<00:00, 331MB/s]
# Downloading (…)neration_config.json: 100%|██████████| 124/124 [00:00<00:00, 17.2kB/s]
# Generated response: What is mlrun?
#
# mlrun is a Python library for running Python code in a Python interpreter. It is a Python wrapper around the standard library.
#
# It is a Python wrapper around the standard library. It is a Python wrapper around the standard library. It is a Python wrapper around the standard library. It is a Python wrapper around the standard library. It is a Python wrapper around the standard library. It is a Python wrapper around the standard library. It is a Python wrapper around
# Generated response: What is an MLRun function?
#
# An MLRun function is a function that takes a list of arguments and returns a list of the arguments.
#
# The following example shows how to use an MLRun function to run a program.
#
# import std.stdio import std.time import std.time.Duration import std.time.Duration.Duration as T import std.time.Duration.Duration.Duration as T.Duration import std.time.Duration.Duration.Duration.
# > 2023-05-07 06:26:19,106 [info] To track results use the CLI: {'info_cmd': 'mlrun get run 4966edac55d34337aa7e345c8c2fe00b -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs 4966edac55d34337aa7e345c8c2fe00b -p learn-docs-dev-admin'}
# > 2023-05-07 06:26:19,106 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/4966edac55d34337aa7e345c8c2fe00b/overview'}
# > 2023-05-07 06:26:19,107 [info] run executed, status=completed: {'name': 'test-llm-load-my-model'}
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>learn-docs-dev-admin</td>
#       <td><div title="4966edac55d34337aa7e345c8c2fe00b"><a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/4966edac55d34337aa7e345c8c2fe00b/overview" target="_blank" >...8c2fe00b</a></div></td>
#       <td>0</td>
#       <td>May 07 06:25:18</td>
#       <td>completed</td>
#       <td>test-llm-load-my-model</td>
#       <td><div class="dictlist">v3io_user=admin</div><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div><div class="dictlist">mlrun/client_version=1.3.0</div><div class="dictlist">mlrun/client_python_version=3.9.16</div><div class="dictlist">host=test-llm-load-my-model-flhbm</div></td>
#       <td></td>
#       <td><div class="dictlist">model_name=gpt2</div></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result483aa39a-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result483aa39a-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result483aa39a" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result483aa39a-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/4966edac55d34337aa7e345c8c2fe00b/overview" target="_blank">click here</a> to open in UI</b>
# > 2023-05-07 06:26:19,147 [info] run executed, status=completed: {'name': 'test-llm-load-my-model'}

# %% [markdown]
# ## Fine-tune this LLM with MLRun dataset

# %%
trainer = project.set_function(
    "src/trainer.py",
    name="hugging_face_classifier_trainer",
    kind="mpijob",
    with_repo=True,
)
trainer.spec.replicas = 4
trainer.with_requests(cpu=5, mem="5Gi")
trainer.with_limits(gpus=1, cpu=8, mem="50Gi")


trainer.apply(mlrun.auto_mount())
trainer.save()
# Out:
# 'db://learn-docs-dev-admin/hugging-face-classifier-trainer'

# %%
params = {
    "model_name": "gpt2-ft-mlrun",
    "pretrained_model": "gpt2",
    "pretrained_tokenizer": "gpt2",
    "model_class": "transformers.GPT2LMHeadModel",
    "tokenizer_class": "transformers.GPT2Tokenizer",
    "random_state": 42,
    "TRAIN_output_dir": os.path.join(base_path, "finetuning-mlrun-data"),
    "TRAIN_overwrite_output_dir": True,
    "TRAIN_num_train_epochs": 2,
    "TRAIN_fp16": True,
    "TRAIN_bf16": False,
    "TRAIN_per_device_train_batch_size": 4,
    "TRAIN_per_device_eval_batch_size": 4,
    "TRAIN_save_steps": 10000,
    "TRAIN_save_total_limit": 2,
    "TRAIN_deepspeed": os.path.join(base_path, "deepspeed_config/stage3.json"),
}

# %%
training_run = mlrun.run_function(
    function="hugging_face_classifier_trainer",
    name="trainer",
    inputs={
            "dataset": train_dataset,  # prepare_dataset_run.outputs["train_dataset"],
            "test_set": test_dataset  # prepare_dataset_run.outputs["test_dataset"],
        },
    params=params,
    handler="train",
    # outputs=["model"],
)
# Out:
# > 2023-05-07 07:04:12,909 [info] Storing function: {'name': 'trainer', 'uid': '12371a463d5d480381d9caab99e5e081', 'db': 'http://mlrun-api:8080'}
# > 2023-05-07 07:04:40,635 [info] MpiJob trainer-1805ace0 launcher pod trainer-1805ace0-launcher state active
# + POD_NAME=trainer-1805ace0-worker-3
# + shift
# + /opt/kube/kubectl exec trainer-1805ace0-worker-3 -- /bin/sh -c  orted -mca ess "env" -mca ess_base_jobid "3095986176" -mca ess_base_vpid 4 -mca ess_base_num_procs "5" -mca orte_node_regex "trainer-[4:1805]ace0-launcher,trainer-[4:1805]ace0-worker-0,trainer-[4:1805]ace0-worker-1,trainer-[4:1805]ace0-worker-2,trainer-[4:1805]ace0-worker-3@0(5)" -mca orte_hnp_uri "3095986176.0;tcp://192.168.139.230:39101" -mca plm "rsh" --tree-spawn -mca routed "radix" -mca orte_parent_uri "3095986176.0;tcp://192.168.139.230:39101" -mca plm_rsh_agent "/etc/mpi/kubexec.sh" -mca orte_default_hostfile "/etc/mpi/hostfile" -mca pmix "^s1,s2,cray,isolated"
# + POD_NAME=trainer-1805ace0-worker-2
# + shift
# + /opt/kube/kubectl exec trainer-1805ace0-worker-2 -- /bin/sh -c  orted -mca ess "env" -mca ess_base_jobid "3095986176" -mca ess_base_vpid 3 -mca ess_base_num_procs "5" -mca orte_node_regex "trainer-[4:1805]ace0-launcher,trainer-[4:1805]ace0-worker-0,trainer-[4:1805]ace0-worker-1,trainer-[4:1805]ace0-worker-2,trainer-[4:1805]ace0-worker-3@0(5)" -mca orte_hnp_uri "3095986176.0;tcp://192.168.139.230:39101" -mca plm "rsh" --tree-spawn -mca routed "radix" -mca orte_parent_uri "3095986176.0;tcp://192.168.139.230:39101" -mca plm_rsh_agent "/etc/mpi/kubexec.sh" -mca orte_default_hostfile "/etc/mpi/hostfile" -mca pmix "^s1,s2,cray,isolated"
# + POD_NAME=trainer-1805ace0-worker-0
# + shift
# + /opt/kube/kubectl exec trainer-1805ace0-worker-0 -- /bin/sh -c  orted -mca ess "env" -mca ess_base_jobid "3095986176" -mca ess_base_vpid 1 -mca ess_base_num_procs "5" -mca orte_node_regex "trainer-[4:1805]ace0-launcher,trainer-[4:1805]ace0-worker-0,trainer-[4:1805]ace0-worker-1,trainer-[4:1805]ace0-worker-2,trainer-[4:1805]ace0-worker-3@0(5)" -mca orte_hnp_uri "3095986176.0;tcp://192.168.139.230:39101" -mca plm "rsh" --tree-spawn -mca routed "radix" -mca orte_parent_uri "3095986176.0;tcp://192.168.139.230:39101" -mca plm_rsh_agent "/etc/mpi/kubexec.sh" -mca orte_default_hostfile "/etc/mpi/hostfile" -mca pmix "^s1,s2,cray,isolated"
# + POD_NAME=trainer-1805ace0-worker-1
# + shift
# + /opt/kube/kubectl exec trainer-1805ace0-worker-1 -- /bin/sh -c  orted -mca ess "env" -mca ess_base_jobid "3095986176" -mca ess_base_vpid 2 -mca ess_base_num_procs "5" -mca orte_node_regex "trainer-[4:1805]ace0-launcher,trainer-[4:1805]ace0-worker-0,trainer-[4:1805]ace0-worker-1,trainer-[4:1805]ace0-worker-2,trainer-[4:1805]ace0-worker-3@0(5)" -mca orte_hnp_uri "3095986176.0;tcp://192.168.139.230:39101" -mca plm "rsh" --tree-spawn -mca routed "radix" -mca orte_parent_uri "3095986176.0;tcp://192.168.139.230:39101" -mca plm_rsh_agent "/etc/mpi/kubexec.sh" -mca orte_default_hostfile "/etc/mpi/hostfile" -mca pmix "^s1,s2,cray,isolated"
#
# Downloading (…)olve/main/vocab.json: 100%|██████████| 1.04M/1.04M [00:00<00:00, 20.8MB/s]
# Downloading (…)olve/main/vocab.json: 100%|██████████| 1.04M/1.04M [00:00<00:00, 19.9MB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 11.8MB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 12.2MB/s]
# Downloading (…)olve/main/vocab.json: 100%|██████████| 1.04M/1.04M [00:00<00:00, 21.9MB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 12.3MB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 665/665 [00:00<00:00, 249kB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 665/665 [00:00<00:00, 249kB/s]
# Downloading (…)olve/main/vocab.json: 100%|██████████| 1.04M/1.04M [00:00<00:00, 20.0MB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 12.5MB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 665/665 [00:00<00:00, 205kB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 665/665 [00:00<00:00, 175kB/s]
# Downloading pytorch_model.bin: 100%|██████████| 548M/548M [00:01<00:00, 449MB/s]
# Downloading pytorch_model.bin: 100%|██████████| 548M/548M [00:01<00:00, 465MB/s]
# Downloading pytorch_model.bin: 100%|██████████| 548M/548M [00:01<00:00, 390MB/s]
# Downloading (…)neration_config.json: 100%|██████████| 124/124 [00:00<00:00, 16.8kB/s]
# [2023-05-07 07:05:10,571] [INFO] [comm.py:570:init_distributed] Not using the DeepSpeed or dist launchers, attempting to detect MPI environment...
# Downloading (…)neration_config.json: 100%|██████████| 124/124 [00:00<00:00, 16.6kB/s]
# [2023-05-07 07:05:10,614] [INFO] [comm.py:570:init_distributed] Not using the DeepSpeed or dist launchers, attempting to detect MPI environment...
# Downloading (…)neration_config.json: 100%|██████████| 124/124 [00:00<00:00, 16.7kB/s]
# [2023-05-07 07:05:12,054] [INFO] [comm.py:570:init_distributed] Not using the DeepSpeed or dist launchers, attempting to detect MPI environment...
# Downloading pytorch_model.bin: 100%|██████████| 548M/548M [00:01<00:00, 482MB/s]
# Downloading (…)neration_config.json: 100%|██████████| 124/124 [00:00<00:00, 20.5kB/s]
# [2023-05-07 07:05:15,864] [INFO] [comm.py:570:init_distributed] Not using the DeepSpeed or dist launchers, attempting to detect MPI environment...
# [2023-05-07 07:05:15,976] [INFO] [comm.py:620:mpi_discovery] Discovered MPI settings of world_rank=3, local_rank=0, world_size=4, master_addr=192.168.245.163, master_port=29500
# [2023-05-07 07:05:15,976] [INFO] [comm.py:620:mpi_discovery] Discovered MPI settings of world_rank=1, local_rank=0, world_size=4, master_addr=192.168.245.163, master_port=29500
# [2023-05-07 07:05:15,976] [INFO] [comm.py:620:mpi_discovery] Discovered MPI settings of world_rank=2, local_rank=0, world_size=4, master_addr=192.168.245.163, master_port=29500
# [2023-05-07 07:05:15,976] [INFO] [comm.py:620:mpi_discovery] Discovered MPI settings of world_rank=0, local_rank=0, world_size=4, master_addr=192.168.245.163, master_port=29500
# [2023-05-07 07:05:15,977] [INFO] [comm.py:586:init_distributed] Initializing TorchBackend in DeepSpeed with backend nccl
# 2023-05-07 07:05:17,047 [info] Added key: store_based_barrier_key:1 to store for rank: 1
# 2023-05-07 07:05:17,102 [info] Added key: store_based_barrier_key:1 to store for rank: 3
# 2023-05-07 07:05:17,147 [info] Added key: store_based_barrier_key:1 to store for rank: 2
# 2023-05-07 07:05:17,195 [info] Added key: store_based_barrier_key:1 to store for rank: 0
# 2023-05-07 07:05:17,196 [info] Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 4 nodes.
# 2023-05-07 07:05:17,198 [info] Rank 2: Completed store-based barrier for key:store_based_barrier_key:1 with 4 nodes.
# 2023-05-07 07:05:17,200 [info] Rank 1: Completed store-based barrier for key:store_based_barrier_key:1 with 4 nodes.
# 2023-05-07 07:05:17,204 [info] Rank 3: Completed store-based barrier for key:store_based_barrier_key:1 with 4 nodes.
# > 2023-05-07 07:05:17,215 [info] training 'gpt2-ft-mlrun'
# > 2023-05-07 07:05:17,217 [info] training 'gpt2-ft-mlrun'
# > 2023-05-07 07:05:17,217 [info] training 'gpt2-ft-mlrun'
# > 2023-05-07 07:05:17,221 [info] training 'gpt2-ft-mlrun'
# 2023-05-07 07:05:20,418 [info] Added key: store_based_barrier_key:2 to store for rank: 2
# 2023-05-07 07:05:20,468 [info] Added key: store_based_barrier_key:2 to store for rank: 3
# 2023-05-07 07:05:20,478 [info] Added key: store_based_barrier_key:2 to store for rank: 1
# 2023-05-07 07:05:20,637 [info] Added key: store_based_barrier_key:2 to store for rank: 0
# 2023-05-07 07:05:20,637 [info] Rank 0: Completed store-based barrier for key:store_based_barrier_key:2 with 4 nodes.
# 2023-05-07 07:05:20,641 [info] Rank 3: Completed store-based barrier for key:store_based_barrier_key:2 with 4 nodes.
# 2023-05-07 07:05:20,641 [info] Rank 1: Completed store-based barrier for key:store_based_barrier_key:2 with 4 nodes.
# 2023-05-07 07:05:20,643 [info] Rank 2: Completed store-based barrier for key:store_based_barrier_key:2 with 4 nodes.
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/cpu_adam...
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/cpu_adam...
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/cpu_adam...
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/cpu_adam...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Detected CUDA files, patching ldflags
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] /opt/conda/bin/nvcc  -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_70,code=compute_70 -gencode=arch=compute_70,code=sm_70 --compiler-options '-fPIC' -O3 --use_fast_math -std=c++14 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -gencode=arch=compute_70,code=sm_70 -gencode=arch=compute_70,code=compute_70 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/common/custom_cuda_kernel.cu -o custom_cuda_kernel.cuda.o
# [1/3] /opt/conda/bin/nvcc  -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_70,code=compute_70 -gencode=arch=compute_70,code=sm_70 --compiler-options '-fPIC' -O3 --use_fast_math -std=c++14 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -gencode=arch=compute_70,code=sm_70 -gencode=arch=compute_70,code=compute_70 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/common/custom_cuda_kernel.cu -o custom_cuda_kernel.cuda.o
# [1/3] /opt/conda/bin/nvcc  -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_70,code=compute_70 -gencode=arch=compute_70,code=sm_70 --compiler-options '-fPIC' -O3 --use_fast_math -std=c++14 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -gencode=arch=compute_70,code=sm_70 -gencode=arch=compute_70,code=compute_70 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/common/custom_cuda_kernel.cu -o custom_cuda_kernel.cuda.o
# [1/3] /opt/conda/bin/nvcc  -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_70,code=compute_70 -gencode=arch=compute_70,code=sm_70 --compiler-options '-fPIC' -O3 --use_fast_math -std=c++14 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -gencode=arch=compute_70,code=sm_70 -gencode=arch=compute_70,code=compute_70 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/common/custom_cuda_kernel.cu -o custom_cuda_kernel.cuda.o
# [2/3] c++ -MMD -MF cpu_adam.o.d -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -O3 -std=c++14 -g -Wno-reorder -L/opt/conda/lib64 -lcudart -lcublas -g -march=native -fopenmp -D__AVX256__ -D__ENABLE_CUDA__ -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/adam/cpu_adam.cpp -o cpu_adam.o
# [3/3] c++ cpu_adam.o custom_cuda_kernel.cuda.o -shared -lcurand -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda_cu -ltorch_cuda_cpp -ltorch -ltorch_python -L/opt/conda/lib64 -lcudart -o cpu_adam.so
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 39.97562646865845 seconds
# [2/3] c++ -MMD -MF cpu_adam.o.d -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -O3 -std=c++14 -g -Wno-reorder -L/opt/conda/lib64 -lcudart -lcublas -g -march=native -fopenmp -D__AVX256__ -D__ENABLE_CUDA__ -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/adam/cpu_adam.cpp -o cpu_adam.o
# [3/3] c++ cpu_adam.o custom_cuda_kernel.cuda.o -shared -lcurand -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda_cu -ltorch_cuda_cpp -ltorch -ltorch_python -L/opt/conda/lib64 -lcudart -o cpu_adam.so
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 40.44740056991577 seconds
# [2/3] c++ -MMD -MF cpu_adam.o.d -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -O3 -std=c++14 -g -Wno-reorder -L/opt/conda/lib64 -lcudart -lcublas -g -march=native -fopenmp -D__AVX256__ -D__ENABLE_CUDA__ -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/adam/cpu_adam.cpp -o cpu_adam.o
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/utils...
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [3/3] c++ cpu_adam.o custom_cuda_kernel.cuda.o -shared -lcurand -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda_cu -ltorch_cuda_cpp -ltorch -ltorch_python -L/opt/conda/lib64 -lcudart -o cpu_adam.so
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 41.38666272163391 seconds
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/utils...
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/utils...
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [2/3] c++ -MMD -MF cpu_adam.o.d -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -O3 -std=c++14 -g -Wno-reorder -L/opt/conda/lib64 -lcudart -lcublas -g -march=native -fopenmp -D__AVX256__ -D__ENABLE_CUDA__ -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/adam/cpu_adam.cpp -o cpu_adam.o
# [3/3] c++ cpu_adam.o custom_cuda_kernel.cuda.o -shared -lcurand -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda_cu -ltorch_cuda_cpp -ltorch -ltorch_python -L/opt/conda/lib64 -lcudart -o cpu_adam.so
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 46.240036725997925 seconds
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py39_cu117/utils...
# Emitting ninja build file /root/.cache/torch_extensions/py39_cu117/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/2] c++ -MMD -MF flatten_unflatten.o.d -DTORCH_EXTENSION_NAME=utils -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/utils/flatten_unflatten.cpp -o flatten_unflatten.o
# [1/2] c++ -MMD -MF flatten_unflatten.o.d -DTORCH_EXTENSION_NAME=utils -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/utils/flatten_unflatten.cpp -o flatten_unflatten.o
# [2/2] c++ flatten_unflatten.o -shared -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -ltorch_cpu -ltorch -ltorch_python -o utils.so
# Loading extension module utils...
# Time to load utils op: 24.25797414779663 seconds
# [2/2] c++ flatten_unflatten.o -shared -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -ltorch_cpu -ltorch -ltorch_python -o utils.so
# Loading extension module utils...
# Time to load utils op: 23.887593746185303 seconds
# [1/2] c++ -MMD -MF flatten_unflatten.o.d -DTORCH_EXTENSION_NAME=utils -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/utils/flatten_unflatten.cpp -o flatten_unflatten.o
# [2/2] c++ flatten_unflatten.o -shared -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -ltorch_cpu -ltorch -ltorch_python -o utils.so
# Loading extension module utils...
# Time to load utils op: 23.6390163898468 seconds
# [1/2] c++ -MMD -MF flatten_unflatten.o.d -DTORCH_EXTENSION_NAME=utils -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /opt/conda/lib/python3.9/site-packages/torch/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.9/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.9/site-packages/torch/include/THC -isystem /opt/conda/include/python3.9 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++14 -c /opt/conda/lib/python3.9/site-packages/deepspeed/ops/csrc/utils/flatten_unflatten.cpp -o flatten_unflatten.o
# [2/2] c++ flatten_unflatten.o -shared -L/opt/conda/lib/python3.9/site-packages/torch/lib -lc10 -ltorch_cpu -ltorch -ltorch_python -o utils.so
# Loading extension module utils...
# Time to load utils op: 22.938963651657104 seconds
# Parameter Offload: Total persistent parameters: 121344 in 98 params
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0005838871002197266 seconds
# Time to load utils op: 0.0005955696105957031 seconds
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0005598068237304688 seconds
#   0%|          | 0/18 [00:00<?, ?it/s]Using /root/.cache/torch_extensions/py39_cu117 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0005385875701904297 seconds
# {'train_runtime': 16.8257, 'train_samples_per_second': 16.047, 'train_steps_per_second': 1.07, 'train_loss': 2.9520399305555554, 'epoch': 2.0}
# {'train_runtime': 16.8365, 'train_samples_per_second': 16.037, 'train_steps_per_second': 1.069, 'train_loss': 2.7799479166666665, 'epoch': 2.0}
# {'train_runtime': 16.8327, 'train_samples_per_second': 16.04, 'train_steps_per_second': 1.069, 'train_loss': 2.9337022569444446, 'epoch': 2.0}
# {'train_runtime': 16.5327, 'train_samples_per_second': 16.331, 'train_steps_per_second': 1.089, 'train_loss': 2.9049479166666665, 'epoch': 2.0}
# 100%|██████████| 18/18 [00:16<00:00,  1.07it/s]
# 100%|██████████| 18/18 [00:16<00:00,  1.07it/s]
# 100%|██████████| 18/18 [00:16<00:00,  1.07it/s]
# 100%|██████████| 18/18 [00:16<00:00,  1.09it/s]
# > 2023-05-07 07:06:58,797 [info] To track results use the CLI: {'info_cmd': 'mlrun get run 12371a463d5d480381d9caab99e5e081 -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs 12371a463d5d480381d9caab99e5e081 -p learn-docs-dev-admin'}
# > 2023-05-07 07:06:58,797 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/12371a463d5d480381d9caab99e5e081/overview'}
# > 2023-05-07 07:06:58,797 [info] run executed, status=running: {'name': 'trainer'}
# > 2023-05-07 07:06:58,809 [info] To track results use the CLI: {'info_cmd': 'mlrun get run 12371a463d5d480381d9caab99e5e081 -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs 12371a463d5d480381d9caab99e5e081 -p learn-docs-dev-admin'}
# > 2023-05-07 07:06:58,809 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/12371a463d5d480381d9caab99e5e081/overview'}
# > 2023-05-07 07:06:58,810 [info] run executed, status=running: {'name': 'trainer'}
# > 2023-05-07 07:06:58,814 [info] To track results use the CLI: {'info_cmd': 'mlrun get run 12371a463d5d480381d9caab99e5e081 -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs 12371a463d5d480381d9caab99e5e081 -p learn-docs-dev-admin'}
# > 2023-05-07 07:06:58,814 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/12371a463d5d480381d9caab99e5e081/overview'}
# > 2023-05-07 07:06:58,815 [info] run executed, status=running: {'name': 'trainer'}
# > 2023-05-07 07:07:00,623 [info] To track results use the CLI: {'info_cmd': 'mlrun get run 12371a463d5d480381d9caab99e5e081 -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs 12371a463d5d480381d9caab99e5e081 -p learn-docs-dev-admin'}
# > 2023-05-07 07:07:00,623 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/12371a463d5d480381d9caab99e5e081/overview'}
# > 2023-05-07 07:07:00,623 [info] run executed, status=running: {'name': 'trainer'}
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>learn-docs-dev-admin</td>
#       <td><div title="12371a463d5d480381d9caab99e5e081"><a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/12371a463d5d480381d9caab99e5e081/overview" target="_blank" >...99e5e081</a></div></td>
#       <td>0</td>
#       <td>May 07 07:04:44</td>
#       <td>completed</td>
#       <td>trainer</td>
#       <td><div class="dictlist">v3io_user=admin</div><div class="dictlist">kind=mpijob</div><div class="dictlist">owner=admin</div><div class="dictlist">mlrun/client_version=1.3.0</div><div class="dictlist">mlrun/client_python_version=3.9.16</div><div class="dictlist">mlrun/job=trainer-1805ace0</div><div class="dictlist">host=trainer-1805ace0-worker-0</div></td>
#       <td><div title="store://datasets/deepspeed-admin/data-prep-prepare-dataset_train_dataset#0:latest">dataset</div><div title="store://datasets/deepspeed-admin/data-prep-prepare-dataset_test_dataset#0:latest">test_set</div></td>
#       <td><div class="dictlist">model_name=gpt2-ft-mlrun</div><div class="dictlist">pretrained_model=gpt2</div><div class="dictlist">pretrained_tokenizer=gpt2</div><div class="dictlist">model_class=transformers.GPT2LMHeadModel</div><div class="dictlist">tokenizer_class=transformers.GPT2Tokenizer</div><div class="dictlist">random_state=42</div><div class="dictlist">TRAIN_output_dir=/User/learn-docs/finetuning-mlrun-data</div><div class="dictlist">TRAIN_overwrite_output_dir=True</div><div class="dictlist">TRAIN_num_train_epochs=2</div><div class="dictlist">TRAIN_fp16=True</div><div class="dictlist">TRAIN_bf16=False</div><div class="dictlist">TRAIN_per_device_train_batch_size=4</div><div class="dictlist">TRAIN_per_device_eval_batch_size=4</div><div class="dictlist">TRAIN_save_steps=10000</div><div class="dictlist">TRAIN_save_total_limit=2</div><div class="dictlist">TRAIN_deepspeed=/User/learn-docs/deepspeed_config/stage3.json</div></td>
#       <td><div class="dictlist">train_runtime=16.5327</div><div class="dictlist">train_samples_per_second=16.331</div><div class="dictlist">train_steps_per_second=1.089</div><div class="dictlist">total_flos=190381457408.0</div><div class="dictlist">train_loss=2.9049479166666665</div></td>
#       <td><div title="v3io:///projects/learn-docs-dev-admin/artifacts/trainer/0/tokenizer.zip">tokenizer</div><div title="v3io:///projects/learn-docs-dev-admin/artifacts/trainer/0/model/">model</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result041cf939-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result041cf939-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result041cf939" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result041cf939-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/12371a463d5d480381d9caab99e5e081/overview" target="_blank">click here</a> to open in UI</b>
# > 2023-05-07 07:07:30,829 [info] run executed, status=completed: {'name': 'trainer'}

# %% [markdown]
# ### Test our fine-tuned model

# %%
model_name = "store://models/deepspeed-admin/gpt2-ft-mlrun#0:latest"
tokenizer_name = "store://artifacts/deepspeed-admin/trainer_tokenizer#0:latest"

# %%
temp_model = os.path.join(base_path, "finetuning-mlrun-data")

# %%
mlrun.run_function(function="test-llm", params={"model_name": temp_model})
# Out:
# > 2023-05-07 07:08:44,250 [info] Storing function: {'name': 'test-llm-load-my-model', 'uid': '99ee9b47b5344138a2767c5607ccb90d', 'db': 'http://mlrun-api:8080'}
# > 2023-05-07 07:08:44,501 [info] Job is running in the background, pod: test-llm-load-my-model-jff67
# Generated response: What is mlrun?
#
# mlrun is a Python library for running Python code in a container. It is a container for running code in a container.
#
# It is a container for running code in a container. It is a container for running code in a container.
#
# It is a container for running code in a container. It is a container for running code in a container.
#
# It is a container for running code in a container. It is a container for running code
# Generated response: What is an MLRun function?
#
# An MLRun function is a function that is executed when the function is called.
#
# It is executed when the function is called with the following parameters:
#
# The function name
#
# The function type
#
# The function parameters
#
# The function parameters
#
# The function parameters
#
# The function parameters
#
# The function parameters
#
# The function parameters
#
# The function parameters
#
# The function parameters
#
# The function parameters
#
# The function parameters
# > 2023-05-07 07:09:59,572 [info] To track results use the CLI: {'info_cmd': 'mlrun get run 99ee9b47b5344138a2767c5607ccb90d -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs 99ee9b47b5344138a2767c5607ccb90d -p learn-docs-dev-admin'}
# > 2023-05-07 07:09:59,572 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/99ee9b47b5344138a2767c5607ccb90d/overview'}
# > 2023-05-07 07:09:59,573 [info] run executed, status=completed: {'name': 'test-llm-load-my-model'}
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>learn-docs-dev-admin</td>
#       <td><div title="99ee9b47b5344138a2767c5607ccb90d"><a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/99ee9b47b5344138a2767c5607ccb90d/overview" target="_blank" >...07ccb90d</a></div></td>
#       <td>0</td>
#       <td>May 07 07:09:00</td>
#       <td>completed</td>
#       <td>test-llm-load-my-model</td>
#       <td><div class="dictlist">v3io_user=admin</div><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div><div class="dictlist">mlrun/client_version=1.3.0</div><div class="dictlist">mlrun/client_python_version=3.9.16</div><div class="dictlist">host=test-llm-load-my-model-jff67</div></td>
#       <td></td>
#       <td><div class="dictlist">model_name=/User/learn-docs/finetuning-mlrun-data</div></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result45a21532-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result45a21532-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result45a21532" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result45a21532-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/99ee9b47b5344138a2767c5607ccb90d/overview" target="_blank">click here</a> to open in UI</b>
# > 2023-05-07 07:10:01,874 [info] run executed, status=completed: {'name': 'test-llm-load-my-model'}

# %% [markdown]
# ## Train on DataBricks Dolly dataset

# %%
prepare_dolly_dataset = project.set_function(
    "src/data_prep_dolly.py",
    name="data-prep-dolly",
    handler="preprocess_dolly",
    kind="job",
)
prepare_dolly_dataset.apply(mlrun.auto_mount())

# %%
prepare_dolly_run = mlrun.run_function(
    function="data-prep-dolly",
    params={"pretrained_tokenizer_name_or_path": temp_model},
    handler="preprocess_dolly",
)
# Out:
# > 2023-05-07 07:11:39,415 [info] Storing function: {'name': 'data-prep-dolly-preprocess-dolly', 'uid': '004b987f67d44632b37b3d69ddf91085', 'db': 'http://mlrun-api:8080'}
# > 2023-05-07 07:11:39,672 [info] Job is running in the background, pod: data-prep-dolly-preprocess-dolly-xj7fx
# > 2023-05-07 07:11:56,640 [info] Loading tokenizer for /User/learn-docs/finetuning-mlrun-data
# > 2023-05-07 07:11:56,832 [info] Loading dataset from databricks/databricks-dolly-15k
# Downloading readme: 100%|██████████| 7.70k/7.70k [00:00<00:00, 8.73MB/s]
# Downloading and preparing dataset json/databricks--databricks-dolly-15k to /root/.cache/huggingface/datasets/databricks___json/databricks--databricks-dolly-15k-6e0f9ea7eaa0ee08/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/13.1M [00:00<?, ?B/s]
# Downloading data:  39%|███▊      | 5.07M/13.1M [00:00<00:00, 50.7MB/s]
# Downloading data: 100%|██████████| 13.1M/13.1M [00:00<00:00, 61.0MB/s]
# Downloading data files: 100%|██████████| 1/1 [00:00<00:00,  2.47it/s]
# Extracting data files: 100%|██████████| 1/1 [00:00<00:00, 1310.31it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/databricks___json/databricks--databricks-dolly-15k-6e0f9ea7eaa0ee08/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4. Subsequent calls will reuse this data.
# 100%|██████████| 1/1 [00:00<00:00, 582.54it/s]
# > 2023-05-07 07:12:02,934 [info] Found 15011 rows
# > 2023-05-07 07:12:04,309 [info] Preprocessing dataset
# > 2023-05-07 07:12:14,481 [info] Processed dataset has 15011 rows
# > 2023-05-07 07:12:17,086 [info] Processed dataset has 14812 rows after filtering for truncated records
# > 2023-05-07 07:12:17,086 [info] Shuffling dataset
# > 2023-05-07 07:12:17,091 [info] Done preprocessing
# > 2023-05-07 07:12:17,098 [info] Train data size: 13812
# > 2023-05-07 07:12:17,098 [info] Test data size: 1000
# > 2023-05-07 07:12:53,412 [info] To track results use the CLI: {'info_cmd': 'mlrun get run 004b987f67d44632b37b3d69ddf91085 -p learn-docs-dev-admin', 'logs_cmd': 'mlrun logs 004b987f67d44632b37b3d69ddf91085 -p learn-docs-dev-admin'}
# > 2023-05-07 07:12:53,412 [info] Or click for UI: {'ui_url': 'https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/004b987f67d44632b37b3d69ddf91085/overview'}
# > 2023-05-07 07:12:53,413 [info] run executed, status=completed: {'name': 'data-prep-dolly-preprocess-dolly'}
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>learn-docs-dev-admin</td>
#       <td><div title="004b987f67d44632b37b3d69ddf91085"><a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/004b987f67d44632b37b3d69ddf91085/overview" target="_blank" >...ddf91085</a></div></td>
#       <td>0</td>
#       <td>May 07 07:11:55</td>
#       <td>completed</td>
#       <td>data-prep-dolly-preprocess-dolly</td>
#       <td><div class="dictlist">v3io_user=admin</div><div class="dictlist">kind=job</div><div class="dictlist">owner=admin</div><div class="dictlist">mlrun/client_version=1.3.0</div><div class="dictlist">mlrun/client_python_version=3.9.16</div><div class="dictlist">host=data-prep-dolly-preprocess-dolly-xj7fx</div></td>
#       <td></td>
#       <td><div class="dictlist">pretrained_tokenizer_name_or_path=/User/learn-docs/finetuning-mlrun-data</div></td>
#       <td></td>
#       <td><div title="v3io:///projects/learn-docs-dev-admin/artifacts/data-prep-dolly-preprocess-dolly/0/train_dolly_dataset.parquet">train_dolly_dataset</div><div title="v3io:///projects/learn-docs-dev-admin/artifacts/data-prep-dolly-preprocess-dolly/0/test_dolly_dataset.parquet">test_dolly_dataset</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result70c950c7-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result70c950c7-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result70c950c7" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result70c950c7-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.llm.iguazio-cd1.com/mlprojects/learn-docs-dev-admin/jobs/monitor/004b987f67d44632b37b3d69ddf91085/overview" target="_blank">click here</a> to open in UI</b>
# > 2023-05-07 07:12:58,236 [info] run executed, status=completed: {'name': 'data-prep-dolly-preprocess-dolly'}

# %%
train_dolly_dataset = "store://artifacts/deepspeed-admin/data-prep-dolly-preprocess-dolly_train_dolly_dataset:74d36220f0134f43a15e3a66710221aa"
test_dolly_dataset = "store://artifacts/deepspeed-admin/data-prep-dolly-preprocess-dolly_test_dolly_dataset:74d36220f0134f43a15e3a66710221aa"

# %%
params= {
    "pretrained_model": os.path.join(base_path, "model-for-dolly"),
    "pretrained_tokenizer": os.path.join(base_path, "model-for-dolly"),
    "model_class": "transformers.GPT2LMHeadModel",
    "tokenizer_class": "transformers.GPT2Tokenizer",
    "require_tokenization": False,
    "TRAIN_deepspeed": os.path.join(base_path, "deepspeed/ds_z3_bf16_config.json"),
    "TRAIN_num_train_epochs": 2,
    "TRAIN_output_dir": "dolly_output",
    "TRAIN_per_device_train_batch_size": 6,
    "TRAIN_per_device_eval_batch_size": 6,
    "TRAIN_logging_steps": 10,
    "TRAIN_save_steps": 200,
    "TRAIN_save_total_limit": 20,
    "TRAIN_eval_steps": 50,
    "TRAIN_warmup_steps": 50,
    "TRAIN_learning_rate": 5e-6,
    "TRAIN_gradient_checkpointing": True,
    "TRAIN_local_rank": True,
    "TRAIN_bf16": False,
    "CLASS_ignore_mismatched_sizes": True,
    "data_collator": "data_collator.DataCollatorForCompletionOnlyLM",
    "DC_mlm": False,
    "DC_return_tensors": "pt",
    "pad_to_multiple_of": 8,
    
}

# %%
 mlrun.run_function(
    function="hugging_face_classifier_trainer",
    name="trainer",
    inputs={
            "dataset": train_dolly_dataset,  # prepare_dolly_run.outputs["train_dolly_dataset"],
            "test_set": test_dataset  # prepare_dolly_run.outputs["test_dolly_dataset"],
        },
    params=params,
    handler="train",
)

# %% [markdown]
# ### Test complete model
